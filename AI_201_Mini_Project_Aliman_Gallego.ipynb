# %% [markdown]
# # Data Exploration

# %%
# import necessary libraries

import pandas as pd
import xgboost as xgb
import torch
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import enefit
import time
import json
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'

print(device)
# Out:
# cuda

# %%
# !nvidia-smi
# Out:
# Wed Jan 17 11:36:47 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla P100-PCIE-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0              27W / 250W |      2MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/predict-energy-behavior-of-prosumers/client.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/gas_prices.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/electricity_prices.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/weather_station_to_county_mapping.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/public_timeseries_testing_util.py
# /kaggle/input/predict-energy-behavior-of-prosumers/historical_weather.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/county_id_to_name_map.json
# /kaggle/input/predict-energy-behavior-of-prosumers/train.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/forecast_weather.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/example_test_files/sample_submission.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/example_test_files/client.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/example_test_files/gas_prices.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/example_test_files/electricity_prices.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/example_test_files/historical_weather.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/example_test_files/revealed_targets.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/example_test_files/test.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/example_test_files/forecast_weather.csv
# /kaggle/input/predict-energy-behavior-of-prosumers/enefit/competition.cpython-310-x86_64-linux-gnu.so
# /kaggle/input/predict-energy-behavior-of-prosumers/enefit/__init__.py
# /kaggle/input/locations/weather_station_to_county_mapping.csv
# /kaggle/input/locations/county_lon_lats.csv

# %% [markdown]
# <h2>Dataset Details</h2>
# <p><strong>train.csv</strong></p>
# <ul>
# <li><code>county</code> - An ID code for the county.</li>
# <li><code>is_business</code> - Boolean for whether or not the prosumer is a business.</li>
# <li><code>product_type</code> - ID code with the following mapping of codes to contract types: <code>{0: "Combined", 1: "Fixed", 2: "General service", 3: "Spot"}</code>.</li>
# <li><code>target</code> - The consumption or production amount for the relevant segment for the hour. The segments are defined by the <code>county</code>, <code>is_business</code>, and <code>product_type</code>.</li>
# <li><code>is_consumption</code> - Boolean for whether or not this row's target is consumption or production.</li>
# <li><code>datetime</code> - The Estonian time in EET (UTC+2) / EEST (UTC+3). It describes the start of the 1-hour period on which target is given.</li>
# <li><code>data_block_id</code> - All rows sharing the same <code>data_block_id</code> will be available at the same forecast time. This is a function of what information is available when forecasts are actually made, at 11 AM each morning. For example, if the forecast weather <code>data_block_id</code> for predictins made on October 31st is 100 then the historic weather <code>data_block_id</code> for October 31st will be 101 as the historic weather data is only actually available the next day.</li>
# <li><code>row_id</code> - A unique identifier for the row.</li>
# <li><code>prediction_unit_id</code> - A unique identifier for the <code>county</code>, <code>is_business</code>, and <code>product_type</code> combination. <em>New prediction units can appear or disappear in the test set.</em></li>
# </ul>
# <p><strong>gas_prices.csv</strong></p>
# <ul>
# <li><code>origin_date</code> - The date when the day-ahead prices became available.</li>
# <li><code>forecast_date</code> - The date when the forecast prices should be relevant.</li>
# <li><code>[lowest/highest]_price_per_mwh</code> - The lowest/highest price of natural gas that on the day ahead market that trading day, in Euros per megawatt hour equivalent.</li>
# <li><code>data_block_id</code></li>
# </ul>
# <p><strong>client.csv</strong></p>
# <ul>
# <li><code>product_type</code></li>
# <li><code>county</code> - An ID code for the county. See <code>county_id_to_name_map.json</code> for the mapping of ID codes to county names.</li>
# <li><code>eic_count</code> - The aggregated number of consumption points (EICs - European Identifier Code).</li>
# <li><code>installed_capacity</code> -  Installed photovoltaic solar panel capacity in kilowatts.</li>
# <li><code>is_business</code> - Boolean for whether or not the prosumer is a business.</li>
# <li><code>date</code></li>
# <li><code>data_block_id</code></li>
# </ul>
# <p><strong>electricity_prices.csv</strong></p>
# <ul>
# <li><code>origin_date</code></li>
# <li><code>forecast_date</code> - Represents the start of the 1-hour period when the price is valid</li>
# <li><code>euros_per_mwh</code> - The price of electricity on the day ahead markets in euros per megawatt hour.</li>
# <li><code>data_block_id</code></li>
# </ul>
# <p><strong>forecast_weather.csv</strong> Weather forecasts that would have been available at prediction time. Sourced from the <a rel="noreferrer nofollow" target="_blank" href="https://codes.ecmwf.int/grib/param-db/?filter=grib2">European Centre for Medium-Range Weather Forecasts</a>.</p>
# <ul>
# <li><code>[latitude/longitude]</code> - The coordinates of the weather forecast.</li>
# <li><code>origin_datetime</code> - The timestamp of when the forecast was generated.</li>
# <li><code>hours_ahead</code> - The number of hours between the forecast generation and the forecast weather. Each forecast covers 48 hours in total.</li>
# <li><code>temperature</code> - The air temperature at 2 meters above ground in degrees Celsius. Estimated for the end of the 1-hour period.</li>
# <li><code>dewpoint</code> - The dew point temperature at 2 meters above ground in degrees Celsius. Estimated for the end of the 1-hour period.</li>
# <li><code>cloudcover_[low/mid/high/total]</code> - The percentage of the sky covered by clouds in the following altitude bands: 0-2 km, 2-6, 6+, and total. Estimated for the end of the 1-hour period.</li>
# <li><code>10_metre_[u/v]_wind_component</code> - The [eastward/northward] component of wind speed measured 10 meters above surface in meters per second. Estimated for the end of the 1-hour period.</li>
# <li><code>data_block_id</code></li>
# <li><code>forecast_datetime</code> - The timestamp of the predicted weather. Generated from <code>origin_datetime</code> plus <code>hours_ahead</code>. This represents the start of the 1-hour period for which weather data are forecasted.</li>
# <li><code>direct_solar_radiation</code> - The direct solar radiation reaching the surface on a plane perpendicular to the direction of the Sun accumulated during the hour, in watt-hours per square meter.</li>
# <li><code>surface_solar_radiation_downwards</code> - The solar radiation, both direct and diffuse, that reaches a horizontal plane at the surface of the Earth, accumulated during the hour, in watt-hours per square meter.</li>
# <li><code>snowfall</code> - Snowfall over hour in units of meters of water equivalent.</li>
# <li><code>total_precipitation</code> - The accumulated liquid, comprising rain and snow that falls on Earth's surface over the described hour, in units of meters.</li>
# </ul>
# <p><strong>historical_weather.csv</strong> <a rel="noreferrer nofollow" target="_blank" href="https://open-meteo.com/en/docs">Historic weather data</a>.</p>
# <ul>
# <li><code>datetime</code> - This represents the start of the 1-hour period for which weather data are measured.</li>
# <li><code>temperature</code> - Measured at the end of the 1-hour period.</li>
# <li><code>dewpoint</code> - Measured at the end of the 1-hour period.</li>
# <li><code>rain</code> - Different from the forecast conventions. The rain from large scale weather systems of the hour in millimeters.</li>
# <li><code>snowfall</code> - Different from the forecast conventions. Snowfall over the hour in centimeters.</li>
# <li><code>surface_pressure</code> - The air pressure at surface in hectopascals.</li>
# <li><code>cloudcover_[low/mid/high/total]</code> - Different from the forecast conventions. Cloud cover at 0-3 km, 3-8, 8+, and total.</li>
# <li><code>windspeed_10m</code> - Different from the forecast conventions. The wind speed at 10 meters above ground in meters per second.</li>
# <li><code>winddirection_10m</code> - Different from the forecast conventions. The wind direction at 10 meters above ground in degrees.</li>
# <li><code>shortwave_radiation</code> - Different from the forecast conventions. The global horizontal irradiation in watt-hours per square meter.</li>
# <li><code>direct_solar_radiation</code></li>
# <li><code>diffuse_radiation</code> - Different from the forecast conventions. The diffuse solar irradiation in watt-hours per square meter.</li>
# <li><code>[latitude/longitude]</code> - The coordinates of the weather station.</li>
# <li><code>data_block_id</code></li>
# </ul>
# </ul>
# <p><strong>client.csv</strong></p>
# <ul>
# <li><code>product_type</code></li>
# <li><code>county</code> - An ID code for the county. See <code>county_id_to_name_map.json</code> for the mapping of ID codes to county names.</li>
# <li><code>longitude</code> - The longitude of a location.</li>
# <li><code>latitude</code> - The latitude of a location.</li>
# </ul>

# %%
input_root_folder = "data"
train = pd.read_csv(f"{input_root_folder}/train.csv")
client = pd.read_csv(f'{input_root_folder}/client.csv')
elec_price = pd.read_csv(f"{input_root_folder}/electricity_prices.csv")
gas_price =  pd.read_csv(f"{input_root_folder}/gas_prices.csv")
forecast_weather =  pd.read_csv(f"{input_root_folder}/forecast_weather.csv")
historical_weather =  pd.read_csv(f"{input_root_folder}/historical_weather.csv")
weather_station =  pd.read_csv(f"{input_root_folder}/weather_station_to_county_mapping.csv")
locations= pd.read_csv(f'{input_root_folder}/county_lon_lats.csv')
locations.drop("Unnamed: 0", axis=1, inplace=True)

# %%
train["datetime"].min(), train["datetime"].max()
# Out:
# ('2021-09-01 00:00:00', '2023-05-31 23:00:00')

# %% [markdown]
# #### Generate county details

# %%
### County population and area size
### http://www.statoids.com/uee.html

with open(f"{input_root_folder}/county_id_to_name_map.json") as f:
    data = json.load(f)
data = {int(key): val for key, val in data.items()}
county_area = {
    0: 4333,
    1: 1023,
    2: 3364,
    3: 2460,
    4: 2604,
    5: 3628,
    6: 2383,
    7: 4807,
    8: 2165,
    9: 2980,
    10: 2922,
    11: 2993,
    12: 2895, # estimate
    13: 2044,
    14: 3422,
    15: 2305
}

county_pop = {
    0: 523588,
    1: 10385,
    2: 177471,
    3: 38514,
    4: 38060,
    5: 67364,
    6: 28394,
    7: 90507,
    8: 32308,
    9: 37319,
    10: 35746,
    11: 149160,
    12: 90749,# estimate
    13: 35479,
    14: 57482,
    15: 39465
}
county_details = {
    "county": [],
    "population": [],
    "area": []
}
for county in county_area:
    county_details["county"].append(county)
    county_details["population"].append(county_pop[county])
    county_details["area"].append(county_area[county])

county_details = pd.DataFrame(county_details)
county_details["popPerArea"] = county_details["population"] / county_details["area"]
county_details
# Out:
#     county  population  area  popPerArea
# 0        0      523588  4333  120.837295
# 1        1       10385  1023   10.151515
# 2        2      177471  3364   52.755945
# 3        3       38514  2460   15.656098
# 4        4       38060  2604   14.615975
# 5        5       67364  3628   18.567806
# 6        6       28394  2383   11.915233
# 7        7       90507  4807   18.828167
# 8        8       32308  2165   14.922864
# 9        9       37319  2980   12.523154
# 10      10       35746  2922   12.233402
# 11      11      149160  2993   49.836285
# 12      12       90749  2895   31.346805
# 13      13       35479  2044   17.357632
# 14      14       57482  3422   16.797779
# 15      15       39465  2305   17.121475

# %% [markdown]
# #### Generate forecasted weather

# %%
forecast_weather[["latitude",'longitude']] = forecast_weather[["latitude",'longitude']].astype(float).round(decimals=1)

forecast_weather= forecast_weather.merge(locations, how='left',
                                             on=['longitude','latitude'])
forecast_weather.dropna(axis= 0, inplace= True)
forecast_weather['county'] = forecast_weather['county'].astype(int)
forecast_weather.drop(['origin_datetime', 'latitude','longitude', 'hours_ahead', 'data_block_id'], axis=1, inplace= True)
forecast_weather.rename(columns={'forecast_datetime': 'datetime'}, inplace= True)
    
#Converting (datetime) column to datetime
forecast_weather['datetime']= pd.to_datetime(forecast_weather['datetime'], utc= True)

### Grouping all forecast_weather columns mean values by hour, So each hour
### will have the mean values of the forecast_weather columns
forecast_weather_datetime= forecast_weather.groupby([forecast_weather['datetime'].dt.to_period('h')])[list(forecast_weather.drop(['county','datetime'], axis= 1).columns)].mean().reset_index()

#After converting the (datetime) column to hour period for the groupby we convert it back to datetime
forecast_weather_datetime['datetime']= pd.to_datetime(forecast_weather_datetime['datetime'].dt.to_timestamp(), utc=True)

## Grouping all forecast_weather columns mean values by hour and county, So each hour and county
## will have the mean values of the forecast_weather columns for each county
forecast_weather_datetime_county= forecast_weather.groupby(['county',forecast_weather['datetime'].dt.to_period('h')])[list(forecast_weather.drop(['county','datetime'], axis= 1).columns)].mean().reset_index()

#After converting the (datetime) column to hour period for the groupby we convert it back to datetime
forecast_weather_datetime_county['datetime']= pd.to_datetime(forecast_weather_datetime_county['datetime'].dt.to_timestamp(), utc=True)
# Out:
# /tmp/ipykernel_32/3095225361.py:15: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   forecast_weather_datetime= forecast_weather.groupby([forecast_weather['datetime'].dt.to_period('h')])[list(forecast_weather.drop(['county','datetime'], axis= 1).columns)].mean().reset_index()
# /tmp/ipykernel_32/3095225361.py:23: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   forecast_weather_datetime_county= forecast_weather.groupby(['county',forecast_weather['datetime'].dt.to_period('h')])[list(forecast_weather.drop(['county','datetime'], axis= 1).columns)].mean().reset_index()

# %% [markdown]
# #### Generate historical weather

# %%
#Rounding the (latitude) and (longitude) for 1 decimal fraction           
historical_weather[['latitude', 'longitude']] = historical_weather[['latitude', 'longitude']].astype(float).round(1)

#Merging counties in locations data with the coordinations in the historical_weather data
historical_weather= historical_weather.merge(locations, how='left', on=['longitude','latitude'])    

#Dropping nan values
historical_weather.dropna(axis= 0, inplace= True)

#Dropping the columns we won't need
historical_weather.drop(['latitude', 'longitude'], axis=1, inplace= True)

#Converting (county) to integer
historical_weather['county'] = historical_weather['county'].astype('int64')

#Converting (datetime) column to datetime
historical_weather['datetime']= pd.to_datetime(historical_weather['datetime'], utc= True)

### Grouping all historical_weather columns mean values by hour, So each hour
### will have the mean values of the historical_weather columns"""     
hist_weather_datetime= historical_weather.groupby([historical_weather['datetime'].dt.to_period('h')])[list(historical_weather.drop(['county','datetime','data_block_id'], axis= 1).columns)].mean().reset_index()    

#After converting the (datetime) column to hour period for the groupby we convert it back to datetime
hist_weather_datetime['datetime']= pd.to_datetime(hist_weather_datetime['datetime'].dt.to_timestamp(), utc=True)

# Merging (data_block_id) back after dropping it in the last step | (data_block_id will be used to merge with train data)
hist_weather_datetime= hist_weather_datetime.merge(
    historical_weather[['datetime', 'data_block_id']], how='left', on='datetime')

### Grouping all historical_weather columns mean values by hour and county, So each hour
### will have the mean values of the historical_weather columns for each county
hist_weather_datetime_county= historical_weather.groupby(['county',historical_weather['datetime'].dt.to_period('h')])[list(historical_weather.drop(['county','datetime', 'data_block_id'], axis= 1).columns)].mean().reset_index() 

# After converting the (datetime) column to hour period for the groupby we convert it back to datetime
hist_weather_datetime_county['datetime']= pd.to_datetime(
    hist_weather_datetime_county['datetime'].dt.to_timestamp(), utc=True)

# Merging (data_block_id) back after dropping it in the last step
hist_weather_datetime_county= hist_weather_datetime_county.merge(historical_weather[['datetime', 'data_block_id']], how='left', on='datetime')

hist_weather_datetime['hour']= hist_weather_datetime['datetime'].dt.hour
hist_weather_datetime_county['hour']= hist_weather_datetime_county['datetime'].dt.hour

#Dropping duplicates and (datetime) column
hist_weather_datetime.drop_duplicates(inplace=True)
hist_weather_datetime_county.drop_duplicates(inplace=True)
hist_weather_datetime.drop('datetime', axis= 1, inplace= True)
hist_weather_datetime_county.drop('datetime', axis= 1, inplace= True)
# Out:
# /tmp/ipykernel_32/3026139309.py:21: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist_weather_datetime= historical_weather.groupby([historical_weather['datetime'].dt.to_period('h')])[list(historical_weather.drop(['county','datetime','data_block_id'], axis= 1).columns)].mean().reset_index()
# /tmp/ipykernel_32/3026139309.py:32: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist_weather_datetime_county= historical_weather.groupby(['county',historical_weather['datetime'].dt.to_period('h')])[list(historical_weather.drop(['county','datetime', 'data_block_id'], axis= 1).columns)].mean().reset_index()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# #### Date time transformations

# %%
# Time features from the train set
train["datetime"] = pd.to_datetime(train["datetime"], utc=True)
train['hour'] = train['datetime'].dt.hour
train['day_of_week'] = train['datetime'].dt.dayofweek
train['day'] = train['datetime'].dt.day
train['month'] = train['datetime'].dt.month
train['year'] = train['datetime'].dt.year
train['quarter'] = train['datetime'].dt.quarter
train['dayofyear'] = train['datetime'].dt.dayofyear
train['sin_hour']= (np.pi * np.sin(train['hour']) / 12)
train['cos_hour']= (np.pi * np.cos(train['hour']) / 12)
train['sin_dayofyear']= (np.pi * np.sin(train['dayofyear']) / 183)
train['cos_dayofyear']= (np.pi * np.cos(train['dayofyear']) / 183)

# %% [markdown]
# Electricity prices transformations

# %%
elec_price["forecast_date"] = pd.to_datetime(elec_price["forecast_date"], utc=True)
elec_price["hour"] = elec_price["forecast_date"].dt.hour
elec_price
# Out:
#                   forecast_date  euros_per_mwh          origin_date  \
# 0     2021-09-01 00:00:00+00:00          92.51  2021-08-31 00:00:00
# 1     2021-09-01 01:00:00+00:00          88.90  2021-08-31 01:00:00
# 2     2021-09-01 02:00:00+00:00          87.35  2021-08-31 02:00:00
# 3     2021-09-01 03:00:00+00:00          86.88  2021-08-31 03:00:00
# 4     2021-09-01 04:00:00+00:00          88.43  2021-08-31 04:00:00
# ...                         ...            ...                  ...
# 15281 2023-05-30 19:00:00+00:00          82.10  2023-05-29 19:00:00
# 15282 2023-05-30 20:00:00+00:00         150.85  2023-05-29 20:00:00
# 15283 2023-05-30 21:00:00+00:00          82.10  2023-05-29 21:00:00
# 15284 2023-05-30 22:00:00+00:00          82.09  2023-05-29 22:00:00
# 15285 2023-05-30 23:00:00+00:00          -1.29  2023-05-29 23:00:00
#
#        data_block_id  hour
# 0                  1     0
# 1                  1     1
# 2                  1     2
# 3                  1     3
# 4                  1     4
# ...              ...   ...
# 15281            637    19
# 15282            637    20
# 15283            637    21
# 15284            637    22
# 15285            637    23
#
# [15286 rows x 5 columns]

# %%
def create_revealed_targets_train(data, lags):
    '''Creating lagged target values | A target value depends on what was a target value n days ago'''
    
    #Storing datetime in a variable
    original_datetime = data['datetime']
    
    #Taking a subset of the following columns from the train data and storing it in a variable
    revealed_targets = data[['datetime', 'prediction_unit_id', 'is_consumption', 'target']].copy()
    
    #Create revealed targets for n days lags
    for day_lag in range(2, lags+1):
        revealed_targets['datetime'] = original_datetime + pd.DateOffset(day_lag)
        data = data.merge(revealed_targets, 
                          how='left', 
                          on = ['datetime', 'prediction_unit_id', 'is_consumption'],
                          suffixes = ('', f'_{day_lag}_days_ago')
                         )
    return data

# %% [markdown]
# #### Mege the datasets and impute missing

# %%
def add_features(df):
    
    df = create_revealed_targets_train(df, lags=num_lag)
    num_lag = 7
    ## Add mean,std,var of the lagged target variables
    df['target_mean']= df[[f'target_{i}_days_ago' for i in range(2, num_lag+1)]].mean(1)
    df['target_std']= df[[f'target_{i}_days_ago' for i in range(2, num_lag+1)]].std(1)
    df['target_var']= df[[f'target_{i}_days_ago' for i in range(2, num_lag+1)]].var(1)

    ## Merge all datasets
    df = (
        df
        .merge(gas_price[["data_block_id","lowest_price_per_mwh","highest_price_per_mwh"]], on=["data_block_id"], how="left")
        .merge(elec_price[["hour","data_block_id", "euros_per_mwh"]], on=["hour","data_block_id"], how="left")
        .merge(client.drop("date",axis=1), on=['data_block_id', 'county', 'is_business', 'product_type'], how="left")
        .merge(forecast_weather_datetime, on=['datetime'], how='left')
        .merge(forecast_weather_datetime_county, on=['datetime', 'county'], suffixes= ('_fcast_mean','_fcast_mean_by_county'), how='left')
        .merge(hist_weather_datetime, on=['data_block_id', 'hour'], how='left')
        .merge(hist_weather_datetime_county, on=['data_block_id', 'county', 'hour'], how='left', suffixes= ('_hist_mean','_hist_mean_by_county'))
        .merge(county_details, on=["county"], how="left")
    )
    df= df.groupby(['year', 'day', 'hour'], as_index=False).apply(lambda x: x.ffill().bfill()).reset_index()
    
    return df

train = add_features(train)

# %% [markdown]
# #### Apply log transformation

# %%
log_this_columns = [
        'target_2_days_ago', 'target_3_days_ago','target_4_days_ago', 'target_5_days_ago', 'target_6_days_ago', 'target_7_days_ago',  
        'target_mean', 'target_std', 'population', 'area','popPerArea'  
        'installed_capacity', 'euros_per_mwh', 'temperature_fcast_mean', 'dewpoint_fcast_mean',
        'cloudcover_high_fcast_mean', 'cloudcover_low_fcast_mean', 'cloudcover_mid_fcast_mean', 'cloudcover_total_fcast_mean',
        '10_metre_u_wind_component_fcast_mean', '10_metre_v_wind_component_fcast_mean', 'direct_solar_radiation_fcast_mean',
        'snowfall_fcast_mean', 'total_precipitation_fcast_mean', 'temperature_fcast_mean_by_county', 'dewpoint_fcast_mean_by_county',
        'cloudcover_high_fcast_mean_by_county', 'cloudcover_low_fcast_mean_by_county', 'cloudcover_mid_fcast_mean_by_county',
        'cloudcover_total_fcast_mean_by_county', '10_metre_u_wind_component_fcast_mean_by_county', '10_metre_v_wind_component_fcast_mean_by_county',
        'surface_solar_radiation_downwards_fcast_mean_by_county', 'snowfall_fcast_mean_by_county', 'total_precipitation_fcast_mean_by_county',
        'rain_hist_mean', 'snowfall_hist_mean', 'windspeed_10m_hist_mean_by_county',         
        ]

for col in log_this_columns:
    train[f"{col}_log"] = np.where((train[col])!= 0, np.log(train[col]),0)
# Out:
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
all_features_raw  = [
    'county', 'is_business', 'product_type','is_consumption',
    'hour', 'day_of_week', 'day', 'month', 'year',
    'quarter', 'dayofyear', 'lowest_price_per_mwh', 'highest_price_per_mwh',
    'euros_per_mwh', 'eic_count', 'installed_capacity',
    'temperature_fcast_mean', 'dewpoint_fcast_mean',
    'cloudcover_high_fcast_mean', 'cloudcover_low_fcast_mean',
    'cloudcover_mid_fcast_mean', 'cloudcover_total_fcast_mean',
    '10_metre_u_wind_component_fcast_mean',
    '10_metre_v_wind_component_fcast_mean',
    'direct_solar_radiation_fcast_mean',
    'surface_solar_radiation_downwards_fcast_mean', 'snowfall_fcast_mean',
    'total_precipitation_fcast_mean', 'temperature_fcast_mean_by_county',
    'dewpoint_fcast_mean_by_county', 'cloudcover_high_fcast_mean_by_county',
    'cloudcover_low_fcast_mean_by_county',
    'cloudcover_mid_fcast_mean_by_county',
    'cloudcover_total_fcast_mean_by_county',
    '10_metre_u_wind_component_fcast_mean_by_county',
    '10_metre_v_wind_component_fcast_mean_by_county',
    'direct_solar_radiation_fcast_mean_by_county',
    'surface_solar_radiation_downwards_fcast_mean_by_county',
    'snowfall_fcast_mean_by_county',
    'total_precipitation_fcast_mean_by_county', 'temperature_hist_mean',
    'dewpoint_hist_mean', 'rain_hist_mean', 'snowfall_hist_mean',
    'surface_pressure_hist_mean', 'cloudcover_total_hist_mean',
    'cloudcover_low_hist_mean', 'cloudcover_mid_hist_mean',
    'cloudcover_high_hist_mean', 'windspeed_10m_hist_mean',
    'winddirection_10m_hist_mean', 'shortwave_radiation_hist_mean',
    'direct_solar_radiation_hist_mean', 'diffuse_radiation_hist_mean',
    'temperature_hist_mean_by_county', 'dewpoint_hist_mean_by_county',
    'rain_hist_mean_by_county', 'snowfall_hist_mean_by_county',
    'surface_pressure_hist_mean_by_county',
    'cloudcover_total_hist_mean_by_county',
    'cloudcover_low_hist_mean_by_county',
    'cloudcover_mid_hist_mean_by_county',
    'cloudcover_high_hist_mean_by_county',
    'windspeed_10m_hist_mean_by_county',
    'winddirection_10m_hist_mean_by_county',
    'shortwave_radiation_hist_mean_by_county',
    'direct_solar_radiation_hist_mean_by_county',
    'diffuse_radiation_hist_mean_by_county', 'population', 'area',
]

# %%
all_features_transformed = [
    'hour','dayofyear',
    'sin_hour', 'cos_hour', 'sin_dayofyear', 'cos_dayofyear',
    
    'day_of_week', 'month','quarter','year', 'county', 'is_business', 'product_type',
    'euros_per_mwh', 'lowest_price_per_mwh', 'highest_price_per_mwh', 'eic_count', 'installed_capacity',
    'temperature_fcast_mean', 'dewpoint_fcast_mean',
    'cloudcover_high_fcast_mean', 'cloudcover_low_fcast_mean',
    'cloudcover_mid_fcast_mean', 'cloudcover_total_fcast_mean',
    '10_metre_u_wind_component_fcast_mean',
    '10_metre_v_wind_component_fcast_mean',
    'direct_solar_radiation_fcast_mean',
    'surface_solar_radiation_downwards_fcast_mean', 'snowfall_fcast_mean',
    'total_precipitation_fcast_mean', 'temperature_fcast_mean_by_county',
    'dewpoint_fcast_mean_by_county', 'cloudcover_high_fcast_mean_by_county',
    'cloudcover_low_fcast_mean_by_county',
    'cloudcover_mid_fcast_mean_by_county',
    'cloudcover_total_fcast_mean_by_county',
    '10_metre_u_wind_component_fcast_mean_by_county',
    '10_metre_v_wind_component_fcast_mean_by_county',
    'direct_solar_radiation_fcast_mean_by_county',
    'surface_solar_radiation_downwards_fcast_mean_by_county',
    'snowfall_fcast_mean_by_county',
    'total_precipitation_fcast_mean_by_county', 'temperature_hist_mean',
    'dewpoint_hist_mean', 'rain_hist_mean', 'snowfall_hist_mean',
    'surface_pressure_hist_mean', 'cloudcover_total_hist_mean',
    'cloudcover_low_hist_mean', 'cloudcover_mid_hist_mean',
    'cloudcover_high_hist_mean', 'windspeed_10m_hist_mean',
    'winddirection_10m_hist_mean', 'shortwave_radiation_hist_mean',
    'direct_solar_radiation_hist_mean', 'diffuse_radiation_hist_mean',
    'temperature_hist_mean_by_county', 'dewpoint_hist_mean_by_county',
    'rain_hist_mean_by_county', 'snowfall_hist_mean_by_county',
    'surface_pressure_hist_mean_by_county',
    'cloudcover_total_hist_mean_by_county',
    'cloudcover_low_hist_mean_by_county',
    'cloudcover_mid_hist_mean_by_county',
    'cloudcover_high_hist_mean_by_county',
    'windspeed_10m_hist_mean_by_county',
    'winddirection_10m_hist_mean_by_county',
    'shortwave_radiation_hist_mean_by_county',
    'direct_solar_radiation_hist_mean_by_county',
    'diffuse_radiation_hist_mean_by_county',
    
    'installed_capacity_log',
    'euros_per_mwh_log',
    'temperature_fcast_mean_log',
    'dewpoint_fcast_mean_log',
    'cloudcover_high_fcast_mean_log',
    'cloudcover_low_fcast_mean_log',
    'cloudcover_mid_fcast_mean_log',
    'cloudcover_total_fcast_mean_log',
    '10_metre_u_wind_component_fcast_mean_log',
    '10_metre_v_wind_component_fcast_mean_log',
    'direct_solar_radiation_fcast_mean_log',
    'snowfall_fcast_mean_log',
    'total_precipitation_fcast_mean_log',
    'temperature_fcast_mean_by_county_log',
    'dewpoint_fcast_mean_by_county_log',
    'cloudcover_high_fcast_mean_by_county_log',
    'cloudcover_low_fcast_mean_by_county_log',
    'cloudcover_mid_fcast_mean_by_county_log',
    'cloudcover_total_fcast_mean_by_county_log',
    '10_metre_u_wind_component_fcast_mean_by_county_log',
    '10_metre_v_wind_component_fcast_mean_by_county_log',
    'surface_solar_radiation_downwards_fcast_mean_by_county_log',
    'snowfall_fcast_mean_by_county_log',
    'total_precipitation_fcast_mean_by_county_log',
    'rain_hist_mean_log',
    'snowfall_hist_mean_log',
    'windspeed_10m_hist_mean_by_county_log',
        
    'target_2_days_ago',
    'target_3_days_ago',
    'target_4_days_ago',
    'target_5_days_ago',
    'target_6_days_ago',
    'target_7_days_ago',
    'target_2_days_ago_log',
    'target_3_days_ago_log',
    'target_4_days_ago_log',
    'target_5_days_ago_log',
    'target_6_days_ago_log',
    'target_7_days_ago_log',
    
    'target_mean', 'target_std', 'target_var',
    'target_mean_log',
    'target_std_log',
]

# %%
selected_features_v1 = [
    'day_of_week',
    'county',
    'eic_count',
    'installed_capacity',
    'surface_solar_radiation_downwards_fcast_mean',
    'snowfall_fcast_mean',
    'cloudcover_low_fcast_mean_by_county',
    'direct_solar_radiation_fcast_mean_by_county',
    'surface_solar_radiation_downwards_fcast_mean_by_county',
    'snowfall_fcast_mean_by_county',
    'direct_solar_radiation_fcast_mean_log',
    'surface_solar_radiation_downwards_fcast_mean_by_county_log',
    'target_2_days_ago',
    'target_6_days_ago',
    'target_7_days_ago',
    'target_2_days_ago_log',
    'target_6_days_ago_log',
    'target_7_days_ago_log',
    'target_mean',
    'target_std',
    'target_var',
    'target_mean_log',
    'target_std_log'
 ]


selected_features_v2 = [
    'day_of_week',
    'county',
    'eic_count',
    'installed_capacity',
    'surface_solar_radiation_downwards_fcast_mean',
    'snowfall_fcast_mean',
    'direct_solar_radiation_fcast_mean_by_county',
    'surface_solar_radiation_downwards_fcast_mean_by_county',
    'snowfall_fcast_mean_by_county',
    'direct_solar_radiation_fcast_mean_log',
    'surface_solar_radiation_downwards_fcast_mean_by_county_log',
    'target_2_days_ago',
    'target_6_days_ago',
    'target_7_days_ago',
    'target_2_days_ago_log',
    'target_6_days_ago_log',
    'target_7_days_ago_log',
    'target_mean',
    'target_std',
    'target_var',
    'target_mean_log',
    'target_std_log'
 ]



selected_features_v3 = [
    'dayofyear', 'target_2_days_ago', 'target_6_days_ago',
       'target_7_days_ago', 'target_mean', 'target_std', 'target_var',
       'day_of_week', 'county', 'is_business', 'eic_count',
       'installed_capacity',
       'surface_solar_radiation_downwards_fcast_mean',
       'cloudcover_low_fcast_mean_by_county',
       'direct_solar_radiation_fcast_mean_by_county',
       'surface_solar_radiation_downwards_fcast_mean_by_county',
       'snowfall_fcast_mean_by_county', 'installed_capacity_log',
       'direct_solar_radiation_fcast_mean_log',
       'surface_solar_radiation_downwards_fcast_mean_by_county_log',
       'target_2_days_ago_log', 'target_6_days_ago_log',
       'target_7_days_ago_log', 'target_mean_log', 'target_std_log'
]

# %%
# choose which feature to use for training
# options (all_features_raw, all_features_transformed, selected_features_v1, selected_features_v2, selected_features_v3)
features = selected_features_v3

# %%
# Prepare the data for training
X = train[features].reset_index(drop=True)
y = train['target'].reset_index(drop=True)

# %%
# Define the cross-validator
tscv = TimeSeriesSplit(n_splits=5)

# Placeholder for the MAE of each fold
mae_scores = []

# Perform Time Series Cross-Validation
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Initialize XGBoost regressor
    model = xgb.XGBRegressor(
        objective='reg:squarederror',
        n_estimators=1000,
        learning_rate=0.01,
        min_child_weight=5,
        max_depth=8,
        subsample=1,
        colsample_bytree=0.7,
        tree_method='gpu_hist',
        eval_metric="mae"
    )

    # Fit the model
    model.fit(X_train, y_train, eval_set=[(X_train, y_train),(X_test, y_test)], early_stopping_rounds=50, verbose=False)

    # Make predictions
    predictions = model.predict(X_test)

    # Calculate and print the MAE
    fold_mae = mean_absolute_error(y_test, predictions)
    mae_scores.append(fold_mae)
    print(f'Fold MAE: {fold_mae}')
# Out:
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# Fold MAE: 92.61205503774889
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# Fold MAE: 45.35265752937994
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# Fold MAE: 41.56985146662197
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# Fold MAE: 58.445178938754644
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# Fold MAE: 59.45528648822021

# %%
# Print the average MAE across all folds
average_mae = sum(mae_scores) / len(mae_scores)
print(f'Average MAE across all folds: {average_mae}')
# Out:
# Average MAE across all folds: 59.487005892145135

# %% [markdown]
# # Hyperparameter Tuning
#
# - run when features = selected_features_v3

# %%
# # Initialize parameters
# params = {
#     'objective': 'reg:squarederror',
#     'eval_metric': 'mae',
#     'tree_method': 'gpu_hist',
#     'n_estimators': 1000,
#     'learning_rate': 0.05
# }

# %%
# gridsearch_params = [
#     (max_depth, min_child_weight, subsample, colsample, eta)
#     for max_depth in range(8, 11, 2)
#     for min_child_weight in range(5, 9, 2)
#     for subsample in [i / 10. for i in range(9, 11)]
#     for colsample in [i / 10. for i in range(7, 9)]
#     for eta in [0.3, 0.01, 0.005]
# ]

# gridsearch_params
# Out:
# [(8, 5, 0.9, 0.7, 0.3),
#  (8, 5, 0.9, 0.7, 0.01),
#  (8, 5, 0.9, 0.7, 0.005),
#  (8, 5, 0.9, 0.8, 0.3),
#  (8, 5, 0.9, 0.8, 0.01),
#  (8, 5, 0.9, 0.8, 0.005),
#  (8, 5, 1.0, 0.7, 0.3),
#  (8, 5, 1.0, 0.7, 0.01),
#  (8, 5, 1.0, 0.7, 0.005),
#  (8, 5, 1.0, 0.8, 0.3),
#  (8, 5, 1.0, 0.8, 0.01),
#  (8, 5, 1.0, 0.8, 0.005),
#  (8, 7, 0.9, 0.7, 0.3),
#  (8, 7, 0.9, 0.7, 0.01),
#  (8, 7, 0.9, 0.7, 0.005),
#  (8, 7, 0.9, 0.8, 0.3),
#  (8, 7, 0.9, 0.8, 0.01),
#  (8, 7, 0.9, 0.8, 0.005),
#  (8, 7, 1.0, 0.7, 0.3),
#  (8, 7, 1.0, 0.7, 0.01),
#  (8, 7, 1.0, 0.7, 0.005),
#  (8, 7, 1.0, 0.8, 0.3),
#  (8, 7, 1.0, 0.8, 0.01),
#  (8, 7, 1.0, 0.8, 0.005),
#  (10, 5, 0.9, 0.7, 0.3),
#  (10, 5, 0.9, 0.7, 0.01),
#  (10, 5, 0.9, 0.7, 0.005),
#  (10, 5, 0.9, 0.8, 0.3),
#  (10, 5, 0.9, 0.8, 0.01),
#  (10, 5, 0.9, 0.8, 0.005),
#  (10, 5, 1.0, 0.7, 0.3),
#  (10, 5, 1.0, 0.7, 0.01),
#  (10, 5, 1.0, 0.7, 0.005),
#  (10, 5, 1.0, 0.8, 0.3),
#  (10, 5, 1.0, 0.8, 0.01),
#  (10, 5, 1.0, 0.8, 0.005),
#  (10, 7, 0.9, 0.7, 0.3),
#  (10, 7, 0.9, 0.7, 0.01),
#  (10, 7, 0.9, 0.7, 0.005),
#  (10, 7, 0.9, 0.8, 0.3),
#  (10, 7, 0.9, 0.8, 0.01),
#  (10, 7, 0.9, 0.8, 0.005),
#  (10, 7, 1.0, 0.7, 0.3),
#  (10, 7, 1.0, 0.7, 0.01),
#  (10, 7, 1.0, 0.7, 0.005),
#  (10, 7, 1.0, 0.8, 0.3),
#  (10, 7, 1.0, 0.8, 0.01),
#  (10, 7, 1.0, 0.8, 0.005)]

# %%
# # Define the cross-validator
# tscv = TimeSeriesSplit(n_splits=5)

# # Initialize minimum MAE, best parameters and DataFrame for results
# min_mae = float("Inf")
# best_params = None
# results_df = pd.DataFrame(columns=['max_depth', 'min_child_weight', 'subsample', 'colsample', 'eta', 'mae', 'time'])

# # Iterate over the combined grid
# for max_depth, min_child_weight, subsample, colsample, eta in tqdm(gridsearch_params, desc="Hyperparameter Tuning Progress"):
#     print(f"Testing params: max_depth={max_depth}, min_child_weight={min_child_weight}, subsample={subsample}, colsample={colsample}, eta={eta}")
    
#     mae_scores = []
#     start_time = time.perf_counter()

#     for train_index, test_index in tscv.split(X):
#         X_train, X_test = X.iloc[train_index], X.iloc[test_index]
#         y_train, y_test = y[train_index], y[test_index]

#         model = xgb.XGBRegressor(
#             objective=params['objective'],
#             n_estimators=params['n_estimators'],
#             learning_rate=eta,
#             max_depth=max_depth,
#             min_child_weight=min_child_weight,
#             subsample=subsample,
#             colsample_bytree=colsample,
#             tree_method=params['tree_method'],
#             early_stopping_rounds=50,
#         )

#         model.fit(X_train, y_train, eval_set=[(X_test, y_test)],  verbose=False)
#         predictions = model.predict(X_test)
#         fold_mae = mean_absolute_error(y_test, predictions)
#         mae_scores.append(fold_mae)

#     end_time = time.perf_counter()
#     elapsed_time = end_time - start_time

#     mean_mae = sum(mae_scores) / len(mae_scores)
#     print(f"\tAverage MAE: {mean_mae} | Time: {elapsed_time:.2f} seconds")

#     new_row = {
#     'max_depth': max_depth,
#     'min_child_weight': min_child_weight,
#     'subsample': subsample,
#     'colsample': colsample,
#     'eta': eta,
#     'mae': mean_mae,
#     'time': elapsed_time
#     }

#     results_df = pd.concat([results_df, pd.DataFrame([new_row])], ignore_index=True)


#     if mean_mae < min_mae:
#         min_mae = mean_mae
#         best_params = (max_depth, min_child_weight, subsample, colsample, eta)

# # Update params with the best found values
# params['max_depth'] = best_params[0]
# params['min_child_weight'] = best_params[1]
# params['subsample'] = best_params[2]
# params['colsample_bytree'] = best_params[3]
# params['eta'] = best_params[4]

# # Print final params
# print(params)
# Out:
# Hyperparameter Tuning Progress:   0%|          | 0/48 [00:00<?, ?it/s]
# Testing params: max_depth=8, min_child_weight=5, subsample=0.9, colsample=0.7, eta=0.3
# Hyperparameter Tuning Progress:   2%|▏         | 1/48 [00:25<20:21, 25.99s/it]
# 	Average MAE: 64.87043952073236 | Time: 25.99 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=0.9, colsample=0.7, eta=0.01
# Hyperparameter Tuning Progress:   4%|▍         | 2/48 [02:18<58:46, 76.66s/it]
# 	Average MAE: 61.723623580711845 | Time: 112.13 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=0.9, colsample=0.7, eta=0.005
# Hyperparameter Tuning Progress:   6%|▋         | 3/48 [04:25<1:14:42, 99.61s/it]
# 	Average MAE: 62.37359690800146 | Time: 126.92 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=0.9, colsample=0.8, eta=0.3
# Hyperparameter Tuning Progress:   8%|▊         | 4/48 [04:49<51:10, 69.78s/it]
# 	Average MAE: 63.63910221909457 | Time: 24.03 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=0.9, colsample=0.8, eta=0.01
# Hyperparameter Tuning Progress:  10%|█         | 5/48 [06:39<1:00:34, 84.52s/it]
# 	Average MAE: 62.50038874810159 | Time: 110.65 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=0.9, colsample=0.8, eta=0.005
# Hyperparameter Tuning Progress:  12%|█▎        | 6/48 [08:46<1:09:19, 99.04s/it]
# 	Average MAE: 63.2856101815157 | Time: 127.24 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=1.0, colsample=0.7, eta=0.3
# Hyperparameter Tuning Progress:  15%|█▍        | 7/48 [09:10<50:54, 74.50s/it]
# 	Average MAE: 65.46181615937112 | Time: 23.95 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=1.0, colsample=0.7, eta=0.01
# Hyperparameter Tuning Progress:  17%|█▋        | 8/48 [10:54<55:46, 83.66s/it]
# 	Average MAE: 62.21693745063732 | Time: 103.29 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=1.0, colsample=0.7, eta=0.005
# Hyperparameter Tuning Progress:  19%|█▉        | 9/48 [12:57<1:02:20, 95.90s/it]
# 	Average MAE: 62.44546096679958 | Time: 122.81 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=1.0, colsample=0.8, eta=0.3
# Hyperparameter Tuning Progress:  21%|██        | 10/48 [13:24<47:24, 74.85s/it]
# 	Average MAE: 64.49836392420002 | Time: 27.70 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=1.0, colsample=0.8, eta=0.01
# Hyperparameter Tuning Progress:  23%|██▎       | 11/48 [15:06<51:18, 83.22s/it]
# 	Average MAE: 62.791502403735976 | Time: 102.19 seconds
# Testing params: max_depth=8, min_child_weight=5, subsample=1.0, colsample=0.8, eta=0.005
# Hyperparameter Tuning Progress:  25%|██▌       | 12/48 [17:10<57:19, 95.53s/it]
# 	Average MAE: 63.34053036725195 | Time: 123.70 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=0.9, colsample=0.7, eta=0.3
# Hyperparameter Tuning Progress:  27%|██▋       | 13/48 [17:34<43:05, 73.89s/it]
# 	Average MAE: 65.05460862801448 | Time: 24.07 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=0.9, colsample=0.7, eta=0.01
# Hyperparameter Tuning Progress:  29%|██▉       | 14/48 [19:20<47:20, 83.56s/it]
# 	Average MAE: 61.80932245925438 | Time: 105.90 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=0.9, colsample=0.7, eta=0.005
# Hyperparameter Tuning Progress:  31%|███▏      | 15/48 [21:26<53:02, 96.44s/it]
# 	Average MAE: 62.44029142875578 | Time: 126.28 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=0.9, colsample=0.8, eta=0.3
# Hyperparameter Tuning Progress:  33%|███▎      | 16/48 [21:51<39:56, 74.90s/it]
# 	Average MAE: 64.37944519864672 | Time: 24.87 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=0.9, colsample=0.8, eta=0.01
# Hyperparameter Tuning Progress:  35%|███▌      | 17/48 [23:42<44:13, 85.59s/it]
# 	Average MAE: 62.37240709598875 | Time: 110.46 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=0.9, colsample=0.8, eta=0.005
# Hyperparameter Tuning Progress:  38%|███▊      | 18/48 [25:50<49:09, 98.33s/it]
# 	Average MAE: 63.39533959698173 | Time: 127.99 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=1.0, colsample=0.7, eta=0.3
# Hyperparameter Tuning Progress:  40%|███▉      | 19/48 [26:17<37:11, 76.95s/it]
# 	Average MAE: 64.33258951800359 | Time: 27.15 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=1.0, colsample=0.7, eta=0.01
# Hyperparameter Tuning Progress:  42%|████▏     | 20/48 [28:06<40:29, 86.76s/it]
# 	Average MAE: 61.86675109736965 | Time: 109.62 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=1.0, colsample=0.7, eta=0.005
# Hyperparameter Tuning Progress:  44%|████▍     | 21/48 [30:10<44:02, 97.88s/it]
# 	Average MAE: 62.47110313092634 | Time: 123.80 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=1.0, colsample=0.8, eta=0.3
# Hyperparameter Tuning Progress:  46%|████▌     | 22/48 [30:35<32:57, 76.06s/it]
# 	Average MAE: 63.58630189167691 | Time: 25.16 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=1.0, colsample=0.8, eta=0.01
# Hyperparameter Tuning Progress:  48%|████▊     | 23/48 [32:24<35:42, 85.71s/it]
# 	Average MAE: 62.56700112460423 | Time: 108.23 seconds
# Testing params: max_depth=8, min_child_weight=7, subsample=1.0, colsample=0.8, eta=0.005
# Hyperparameter Tuning Progress:  50%|█████     | 24/48 [34:27<38:45, 96.90s/it]
# 	Average MAE: 63.39434040377354 | Time: 122.99 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=0.9, colsample=0.7, eta=0.3
# Hyperparameter Tuning Progress:  52%|█████▏    | 25/48 [34:52<28:57, 75.55s/it]
# 	Average MAE: 62.94245378564209 | Time: 25.75 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=0.9, colsample=0.7, eta=0.01
# Hyperparameter Tuning Progress:  54%|█████▍    | 26/48 [37:24<36:06, 98.45s/it]
# 	Average MAE: 59.45401744643307 | Time: 151.89 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=0.9, colsample=0.7, eta=0.005
# Hyperparameter Tuning Progress:  56%|█████▋    | 27/48 [40:32<43:52, 125.36s/it]
# 	Average MAE: 60.02024392142365 | Time: 188.12 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=0.9, colsample=0.8, eta=0.3
# Hyperparameter Tuning Progress:  58%|█████▊    | 28/48 [40:59<31:55, 95.75s/it]
# 	Average MAE: 62.29057991285364 | Time: 26.67 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=0.9, colsample=0.8, eta=0.01
# Hyperparameter Tuning Progress:  60%|██████    | 29/48 [43:24<35:02, 110.64s/it]
# 	Average MAE: 60.26963157341292 | Time: 145.36 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=0.9, colsample=0.8, eta=0.005
# Hyperparameter Tuning Progress:  62%|██████▎   | 30/48 [46:32<40:04, 133.61s/it]
# 	Average MAE: 60.7109565534159 | Time: 187.20 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=1.0, colsample=0.7, eta=0.3
# Hyperparameter Tuning Progress:  65%|██████▍   | 31/48 [46:57<28:39, 101.17s/it]
# 	Average MAE: 62.25681674148548 | Time: 25.50 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=1.0, colsample=0.7, eta=0.01
# Hyperparameter Tuning Progress:  67%|██████▋   | 32/48 [49:18<30:09, 113.12s/it]
# 	Average MAE: 60.31045601345446 | Time: 140.99 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=1.0, colsample=0.7, eta=0.005
# Hyperparameter Tuning Progress:  69%|██████▉   | 33/48 [52:21<33:32, 134.15s/it]
# 	Average MAE: 60.39464492491233 | Time: 183.21 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=1.0, colsample=0.8, eta=0.3
# Hyperparameter Tuning Progress:  71%|███████   | 34/48 [52:48<23:44, 101.74s/it]
# 	Average MAE: 63.17615329365951 | Time: 26.10 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=1.0, colsample=0.8, eta=0.01
# Hyperparameter Tuning Progress:  73%|███████▎  | 35/48 [55:10<24:41, 113.96s/it]
# 	Average MAE: 61.3152434899351 | Time: 142.48 seconds
# Testing params: max_depth=10, min_child_weight=5, subsample=1.0, colsample=0.8, eta=0.005
# Hyperparameter Tuning Progress:  75%|███████▌  | 36/48 [58:14<26:58, 134.91s/it]
# 	Average MAE: 61.57744748883092 | Time: 183.78 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=0.9, colsample=0.7, eta=0.3
# Hyperparameter Tuning Progress:  77%|███████▋  | 37/48 [58:40<18:45, 102.33s/it]
# 	Average MAE: 62.877149930947084 | Time: 26.32 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=0.9, colsample=0.7, eta=0.01
# Hyperparameter Tuning Progress:  79%|███████▉  | 38/48 [1:00:59<18:53, 113.37s/it]
# 	Average MAE: 59.65550081666 | Time: 139.13 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=0.9, colsample=0.7, eta=0.005
# Hyperparameter Tuning Progress:  81%|████████▏ | 39/48 [1:04:04<20:13, 134.79s/it]
# 	Average MAE: 59.93705710106584 | Time: 184.76 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=0.9, colsample=0.8, eta=0.3
# Hyperparameter Tuning Progress:  83%|████████▎ | 40/48 [1:04:31<13:39, 102.48s/it]
# 	Average MAE: 62.362856233993725 | Time: 27.06 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=0.9, colsample=0.8, eta=0.01
# Hyperparameter Tuning Progress:  85%|████████▌ | 41/48 [1:06:52<13:17, 113.90s/it]
# 	Average MAE: 60.53316047852288 | Time: 140.55 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=0.9, colsample=0.8, eta=0.005
# Hyperparameter Tuning Progress:  88%|████████▊ | 42/48 [1:09:56<13:31, 135.18s/it]
# 	Average MAE: 60.78409440960543 | Time: 184.84 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=1.0, colsample=0.7, eta=0.3
# Hyperparameter Tuning Progress:  90%|████████▉ | 43/48 [1:10:25<08:35, 103.14s/it]
# 	Average MAE: 62.94574943470887 | Time: 28.37 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=1.0, colsample=0.7, eta=0.01
# Hyperparameter Tuning Progress:  92%|█████████▏| 44/48 [1:12:46<07:38, 114.60s/it]
# 	Average MAE: 60.172431740970424 | Time: 141.33 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=1.0, colsample=0.7, eta=0.005
# Hyperparameter Tuning Progress:  94%|█████████▍| 45/48 [1:15:49<06:44, 134.92s/it]
# 	Average MAE: 60.23988566739049 | Time: 182.32 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=1.0, colsample=0.8, eta=0.3
# Hyperparameter Tuning Progress:  96%|█████████▌| 46/48 [1:16:14<03:24, 102.03s/it]
# 	Average MAE: 63.08747110760834 | Time: 25.30 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=1.0, colsample=0.8, eta=0.01
# Hyperparameter Tuning Progress:  98%|█████████▊| 47/48 [1:18:25<01:50, 110.63s/it]
# 	Average MAE: 61.22076102784293 | Time: 130.68 seconds
# Testing params: max_depth=10, min_child_weight=7, subsample=1.0, colsample=0.8, eta=0.005
# Hyperparameter Tuning Progress: 100%|██████████| 48/48 [1:21:27<00:00, 101.81s/it]
# 	Average MAE: 61.58321111300624 | Time: 182.03 seconds
# {'objective': 'reg:squarederror', 'eval_metric': 'mae', 'tree_method': 'gpu_hist', 'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 10, 'min_child_weight': 5, 'subsample': 0.9, 'colsample_bytree': 0.7, 'eta': 0.01}

# %%
# # saving the dataframe
# results_df.to_csv('hyperparam_tuning_df.csv')

# results_df
# Out:
#    max_depth min_child_weight  subsample  colsample    eta        mae  \
# 0          8                5        0.9        0.7  0.300  64.870440
# 1          8                5        0.9        0.7  0.010  61.723624
# 2          8                5        0.9        0.7  0.005  62.373597
# 3          8                5        0.9        0.8  0.300  63.639102
# 4          8                5        0.9        0.8  0.010  62.500389
# 5          8                5        0.9        0.8  0.005  63.285610
# 6          8                5        1.0        0.7  0.300  65.461816
# 7          8                5        1.0        0.7  0.010  62.216937
# 8          8                5        1.0        0.7  0.005  62.445461
# 9          8                5        1.0        0.8  0.300  64.498364
# 10         8                5        1.0        0.8  0.010  62.791502
# 11         8                5        1.0        0.8  0.005  63.340530
# 12         8                7        0.9        0.7  0.300  65.054609
# 13         8                7        0.9        0.7  0.010  61.809322
# 14         8                7        0.9        0.7  0.005  62.440291
# 15         8                7        0.9        0.8  0.300  64.379445
# 16         8                7        0.9        0.8  0.010  62.372407
# 17         8                7        0.9        0.8  0.005  63.395340
# 18         8                7        1.0        0.7  0.300  64.332590
# 19         8                7        1.0        0.7  0.010  61.866751
# 20         8                7        1.0        0.7  0.005  62.471103
# 21         8                7        1.0        0.8  0.300  63.586302
# 22         8                7        1.0        0.8  0.010  62.567001
# 23         8                7        1.0        0.8  0.005  63.394340
# 24        10                5        0.9        0.7  0.300  62.942454
# 25        10                5        0.9        0.7  0.010  59.454017
# 26        10                5        0.9        0.7  0.005  60.020244
# 27        10                5        0.9        0.8  0.300  62.290580
# 28        10                5        0.9        0.8  0.010  60.269632
# 29        10                5        0.9        0.8  0.005  60.710957
# 30        10                5        1.0        0.7  0.300  62.256817
# 31        10                5        1.0        0.7  0.010  60.310456
# 32        10                5        1.0        0.7  0.005  60.394645
# 33        10                5        1.0        0.8  0.300  63.176153
# 34        10                5        1.0        0.8  0.010  61.315243
# 35        10                5        1.0        0.8  0.005  61.577447
# 36        10                7        0.9        0.7  0.300  62.877150
# 37        10                7        0.9        0.7  0.010  59.655501
# 38        10                7        0.9        0.7  0.005  59.937057
# 39        10                7        0.9        0.8  0.300  62.362856
# 40        10                7        0.9        0.8  0.010  60.533160
# 41        10                7        0.9        0.8  0.005  60.784094
# 42        10                7        1.0        0.7  0.300  62.945749
# 43        10                7        1.0        0.7  0.010  60.172432
# 44        10                7        1.0        0.7  0.005  60.239886
# 45        10                7        1.0        0.8  0.300  63.087471
# 46        10                7        1.0        0.8  0.010  61.220761
# 47        10                7        1.0        0.8  0.005  61.583211
#
#           time
# 0    25.986456
# 1   112.125522
# 2   126.924967
# 3    24.029246
# 4   110.649843
# 5   127.236056
# 6    23.951245
# 7   103.285509
# 8   122.807689
# 9    27.696551
# 10  102.189572
# 11  123.697994
# 12   24.072952
# 13  105.902246
# 14  126.282465
# 15   24.868085
# 16  110.458394
# 17  127.987686
# 18   27.154884
# 19  109.623090
# 20  123.797880
# 21   25.162752
# 22  108.227595
# 23  122.985303
# 24   25.746000
# 25  151.888290
# 26  188.122042
# 27   26.671963
# 28  145.364772
# 29  187.196075
# 30   25.496327
# 31  140.993446
# 32  183.211223
# 33   26.100680
# 34  142.475787
# 35  183.777924
# 36   26.320475
# 37  139.132828
# 38  184.764771
# 39   27.063901
# 40  140.547730
# 41  184.837597
# 42   28.370794
# 43  141.325550
# 44  182.321359
# 45   25.302502
# 46  130.684893
# 47  182.033019

# %% [markdown]
# # Model
#
# - change hyperparameters according to the model version
#     - default hyperparameters: {learning_rate=0.01, max_depth=8, min_child_weight = 5, subsample = 1, colsample_bytree=0.7}
#     - best hyperparameters: {learning_rate=0.01, max_depth=10, min_child_weight = 7, subsample = 0.9, colsample_bytree=0.7}

# %%
# Splitting the dataset
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)

# Fit the model on the entire dataset
final_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=10000,
    learning_rate=0.01,
    max_depth=8,
    min_child_weight=5,
    subsample=1,
    colsample_bytree=0.7,
    tree_method='gpu_hist',
    eval_metric='mae',
    early_stopping_rounds=100
)

# Fit the model
final_model.fit(
    X_train, y_train, 
    eval_set=[(X_train, y_train), (X_val, y_val)], 
    verbose=True
)

# Capture the training and validation metrics
evals_result = final_model.evals_result()

# Create a DataFrame from the metrics
results_df_2 = pd.DataFrame({
    'train': evals_result['validation_0']['mae'],
    'validation': evals_result['validation_1']['mae']
})

# saving the dataframe
results_df_2.to_csv('model_train_val_df.csv')
# Out:
# [0]	validation_0-mae:271.63570	validation_1-mae:272.68724
# [1]	validation_0-mae:268.93735	validation_1-mae:269.97888
# [2]	validation_0-mae:266.27617	validation_1-mae:267.31215
# [3]	validation_0-mae:263.63942	validation_1-mae:264.66590
# [4]	validation_0-mae:261.03333	validation_1-mae:262.05207
# [5]	validation_0-mae:258.45791	validation_1-mae:259.47010
# [6]	validation_0-mae:255.91309	validation_1-mae:256.92046
# [7]	validation_0-mae:253.39886	validation_1-mae:254.39887
# [8]	validation_0-mae:250.91268	validation_1-mae:251.90574
# [9]	validation_0-mae:248.45454	validation_1-mae:249.44087
# [10]	validation_0-mae:246.02776	validation_1-mae:247.00754
# [11]	validation_0-mae:243.62952	validation_1-mae:244.60505
# [12]	validation_0-mae:241.25783	validation_1-mae:242.22739
# [13]	validation_0-mae:238.91503	validation_1-mae:239.88280
# [14]	validation_0-mae:236.60017	validation_1-mae:237.56517
# [15]	validation_0-mae:234.31122	validation_1-mae:235.27131
# [16]	validation_0-mae:232.04989	validation_1-mae:233.00488
# [17]	validation_0-mae:229.81459	validation_1-mae:230.76576
# [18]	validation_0-mae:227.60379	validation_1-mae:228.55126
# [19]	validation_0-mae:225.41849	validation_1-mae:226.35945
# [20]	validation_0-mae:223.25859	validation_1-mae:224.19563
# [21]	validation_0-mae:221.12243	validation_1-mae:222.05263
# [22]	validation_0-mae:219.01256	validation_1-mae:219.93730
# [23]	validation_0-mae:216.93022	validation_1-mae:217.84836
# [24]	validation_0-mae:214.86716	validation_1-mae:215.77829
# [25]	validation_0-mae:212.82714	validation_1-mae:213.73537
# [26]	validation_0-mae:210.81163	validation_1-mae:211.71764
# [27]	validation_0-mae:208.81929	validation_1-mae:209.72099
# [28]	validation_0-mae:206.85274	validation_1-mae:207.75289
# [29]	validation_0-mae:204.90513	validation_1-mae:205.80023
# [30]	validation_0-mae:202.98152	validation_1-mae:203.87369
# [31]	validation_0-mae:201.07969	validation_1-mae:201.96836
# [32]	validation_0-mae:199.19735	validation_1-mae:200.08028
# [33]	validation_0-mae:197.33886	validation_1-mae:198.21790
# [34]	validation_0-mae:195.50018	validation_1-mae:196.37495
# [35]	validation_0-mae:193.68510	validation_1-mae:194.55793
# [36]	validation_0-mae:191.88955	validation_1-mae:192.75716
# [37]	validation_0-mae:190.11603	validation_1-mae:190.98049
# [38]	validation_0-mae:188.36067	validation_1-mae:189.21967
# [39]	validation_0-mae:186.62685	validation_1-mae:187.48308
# [40]	validation_0-mae:184.91413	validation_1-mae:185.76609
# [41]	validation_0-mae:183.21939	validation_1-mae:184.06826
# [42]	validation_0-mae:181.54526	validation_1-mae:182.39089
# [43]	validation_0-mae:179.88586	validation_1-mae:180.72621
# [44]	validation_0-mae:178.24953	validation_1-mae:179.08684
# [45]	validation_0-mae:176.63020	validation_1-mae:177.46390
# [46]	validation_0-mae:175.02758	validation_1-mae:175.85932
# [47]	validation_0-mae:173.44566	validation_1-mae:174.27428
# [48]	validation_0-mae:171.88967	validation_1-mae:172.71430
# [49]	validation_0-mae:170.34170	validation_1-mae:171.16312
# [50]	validation_0-mae:168.81097	validation_1-mae:169.63026
# [51]	validation_0-mae:167.29945	validation_1-mae:168.11610
# [52]	validation_0-mae:165.80418	validation_1-mae:166.61756
# [53]	validation_0-mae:164.32599	validation_1-mae:165.13585
# [54]	validation_0-mae:162.86646	validation_1-mae:163.67581
# [55]	validation_0-mae:161.42433	validation_1-mae:162.23088
# [56]	validation_0-mae:160.00417	validation_1-mae:160.80829
# [57]	validation_0-mae:158.59397	validation_1-mae:159.39684
# [58]	validation_0-mae:157.19859	validation_1-mae:157.99894
# [59]	validation_0-mae:155.82132	validation_1-mae:156.61885
# [60]	validation_0-mae:154.46554	validation_1-mae:155.26193
# [61]	validation_0-mae:153.11802	validation_1-mae:153.91146
# [62]	validation_0-mae:151.78633	validation_1-mae:152.57937
# [63]	validation_0-mae:150.46973	validation_1-mae:151.26107
# [64]	validation_0-mae:149.16707	validation_1-mae:149.95750
# [65]	validation_0-mae:147.88136	validation_1-mae:148.66860
# [66]	validation_0-mae:146.60920	validation_1-mae:147.39566
# [67]	validation_0-mae:145.35024	validation_1-mae:146.13428
# [68]	validation_0-mae:144.11108	validation_1-mae:144.89344
# [69]	validation_0-mae:142.88131	validation_1-mae:143.66269
# [70]	validation_0-mae:141.66860	validation_1-mae:142.44563
# [71]	validation_0-mae:140.46796	validation_1-mae:141.24091
# [72]	validation_0-mae:139.28155	validation_1-mae:140.05319
# [73]	validation_0-mae:138.11304	validation_1-mae:138.88008
# [74]	validation_0-mae:136.95347	validation_1-mae:137.71884
# [75]	validation_0-mae:135.81102	validation_1-mae:136.57350
# [76]	validation_0-mae:134.68618	validation_1-mae:135.44627
# [77]	validation_0-mae:133.56615	validation_1-mae:134.32206
# [78]	validation_0-mae:132.45845	validation_1-mae:133.21102
# [79]	validation_0-mae:131.36689	validation_1-mae:132.11738
# [80]	validation_0-mae:130.28663	validation_1-mae:131.03372
# [81]	validation_0-mae:129.21767	validation_1-mae:129.96206
# [82]	validation_0-mae:128.16594	validation_1-mae:128.90818
# [83]	validation_0-mae:127.12132	validation_1-mae:127.86246
# [84]	validation_0-mae:126.08666	validation_1-mae:126.82577
# [85]	validation_0-mae:125.06731	validation_1-mae:125.80545
# [86]	validation_0-mae:124.05796	validation_1-mae:124.79330
# [87]	validation_0-mae:123.06307	validation_1-mae:123.79396
# [88]	validation_0-mae:122.07556	validation_1-mae:122.80582
# [89]	validation_0-mae:121.10328	validation_1-mae:121.83252
# [90]	validation_0-mae:120.14249	validation_1-mae:120.86853
# [91]	validation_0-mae:119.19264	validation_1-mae:119.91543
# [92]	validation_0-mae:118.24814	validation_1-mae:118.96907
# [93]	validation_0-mae:117.31998	validation_1-mae:118.03875
# [94]	validation_0-mae:116.39857	validation_1-mae:117.11459
# [95]	validation_0-mae:115.48628	validation_1-mae:116.19995
# [96]	validation_0-mae:114.58651	validation_1-mae:115.29943
# [97]	validation_0-mae:113.69677	validation_1-mae:114.40758
# [98]	validation_0-mae:112.81649	validation_1-mae:113.52583
# [99]	validation_0-mae:111.95050	validation_1-mae:112.65770
# [100]	validation_0-mae:111.09335	validation_1-mae:111.79978
# [101]	validation_0-mae:110.24797	validation_1-mae:110.95283
# [102]	validation_0-mae:109.40985	validation_1-mae:110.11170
# [103]	validation_0-mae:108.57794	validation_1-mae:109.27672
# [104]	validation_0-mae:107.76170	validation_1-mae:108.45873
# [105]	validation_0-mae:106.94792	validation_1-mae:107.64504
# [106]	validation_0-mae:106.14694	validation_1-mae:106.84212
# [107]	validation_0-mae:105.35266	validation_1-mae:106.04629
# [108]	validation_0-mae:104.57072	validation_1-mae:105.26434
# [109]	validation_0-mae:103.79455	validation_1-mae:104.48820
# [110]	validation_0-mae:103.03188	validation_1-mae:103.72473
# [111]	validation_0-mae:102.27476	validation_1-mae:102.96704
# [112]	validation_0-mae:101.52693	validation_1-mae:102.22005
# [113]	validation_0-mae:100.78994	validation_1-mae:101.48513
# [114]	validation_0-mae:100.06246	validation_1-mae:100.75862
# [115]	validation_0-mae:99.34207	validation_1-mae:100.03742
# [116]	validation_0-mae:98.62987	validation_1-mae:99.32694
# [117]	validation_0-mae:97.92130	validation_1-mae:98.61981
# [118]	validation_0-mae:97.22881	validation_1-mae:97.92676
# [119]	validation_0-mae:96.53978	validation_1-mae:97.23911
# [120]	validation_0-mae:95.85744	validation_1-mae:96.55978
# [121]	validation_0-mae:95.18605	validation_1-mae:95.88800
# [122]	validation_0-mae:94.52270	validation_1-mae:95.22509
# [123]	validation_0-mae:93.86512	validation_1-mae:94.56751
# [124]	validation_0-mae:93.21496	validation_1-mae:93.91554
# [125]	validation_0-mae:92.57300	validation_1-mae:93.27625
# [126]	validation_0-mae:91.93664	validation_1-mae:92.64110
# [127]	validation_0-mae:91.30763	validation_1-mae:92.01363
# [128]	validation_0-mae:90.68600	validation_1-mae:91.39332
# [129]	validation_0-mae:90.07728	validation_1-mae:90.78475
# [130]	validation_0-mae:89.47224	validation_1-mae:90.18080
# [131]	validation_0-mae:88.86673	validation_1-mae:89.57598
# [132]	validation_0-mae:88.27681	validation_1-mae:88.98769
# [133]	validation_0-mae:87.68911	validation_1-mae:88.40202
# [134]	validation_0-mae:87.11648	validation_1-mae:87.82947
# [135]	validation_0-mae:86.54825	validation_1-mae:87.26242
# [136]	validation_0-mae:85.98592	validation_1-mae:86.70082
# [137]	validation_0-mae:85.43374	validation_1-mae:86.14962
# [138]	validation_0-mae:84.87925	validation_1-mae:85.59717
# [139]	validation_0-mae:84.33775	validation_1-mae:85.05731
# [140]	validation_0-mae:83.80185	validation_1-mae:84.52315
# [141]	validation_0-mae:83.27139	validation_1-mae:83.99552
# [142]	validation_0-mae:82.74743	validation_1-mae:83.47486
# [143]	validation_0-mae:82.22655	validation_1-mae:82.95455
# [144]	validation_0-mae:81.71770	validation_1-mae:82.44897
# [145]	validation_0-mae:81.21460	validation_1-mae:81.94683
# [146]	validation_0-mae:80.71035	validation_1-mae:81.44449
# [147]	validation_0-mae:80.22257	validation_1-mae:80.95715
# [148]	validation_0-mae:79.73525	validation_1-mae:80.47060
# [149]	validation_0-mae:79.25178	validation_1-mae:79.98754
# [150]	validation_0-mae:78.77333	validation_1-mae:79.50926
# [151]	validation_0-mae:78.30583	validation_1-mae:79.04233
# [152]	validation_0-mae:77.84705	validation_1-mae:78.58460
# [153]	validation_0-mae:77.39446	validation_1-mae:78.13389
# [154]	validation_0-mae:76.94205	validation_1-mae:77.68253
# [155]	validation_0-mae:76.49641	validation_1-mae:77.23843
# [156]	validation_0-mae:76.05610	validation_1-mae:76.79957
# [157]	validation_0-mae:75.62009	validation_1-mae:76.36492
# [158]	validation_0-mae:75.18455	validation_1-mae:75.93143
# [159]	validation_0-mae:74.75808	validation_1-mae:75.50700
# [160]	validation_0-mae:74.33810	validation_1-mae:75.09025
# [161]	validation_0-mae:73.92375	validation_1-mae:74.67693
# [162]	validation_0-mae:73.50988	validation_1-mae:74.26509
# [163]	validation_0-mae:73.10002	validation_1-mae:73.85628
# [164]	validation_0-mae:72.70000	validation_1-mae:73.45919
# [165]	validation_0-mae:72.30148	validation_1-mae:73.06222
# [166]	validation_0-mae:71.91137	validation_1-mae:72.67284
# [167]	validation_0-mae:71.52318	validation_1-mae:72.28769
# [168]	validation_0-mae:71.14172	validation_1-mae:71.90671
# [169]	validation_0-mae:70.76860	validation_1-mae:71.53527
# [170]	validation_0-mae:70.39196	validation_1-mae:71.16145
# [171]	validation_0-mae:70.02217	validation_1-mae:70.79377
# [172]	validation_0-mae:69.65933	validation_1-mae:70.43302
# [173]	validation_0-mae:69.30188	validation_1-mae:70.07714
# [174]	validation_0-mae:68.94196	validation_1-mae:69.71930
# [175]	validation_0-mae:68.59472	validation_1-mae:69.37393
# [176]	validation_0-mae:68.25173	validation_1-mae:69.03187
# [177]	validation_0-mae:67.90421	validation_1-mae:68.68845
# [178]	validation_0-mae:67.57174	validation_1-mae:68.35684
# [179]	validation_0-mae:67.24337	validation_1-mae:68.03060
# [180]	validation_0-mae:66.91399	validation_1-mae:67.70375
# [181]	validation_0-mae:66.58859	validation_1-mae:67.38105
# [182]	validation_0-mae:66.27154	validation_1-mae:67.06696
# [183]	validation_0-mae:65.94878	validation_1-mae:66.74663
# [184]	validation_0-mae:65.63631	validation_1-mae:66.43772
# [185]	validation_0-mae:65.32607	validation_1-mae:66.13146
# [186]	validation_0-mae:65.01995	validation_1-mae:65.82837
# [187]	validation_0-mae:64.72117	validation_1-mae:65.53157
# [188]	validation_0-mae:64.42458	validation_1-mae:65.23840
# [189]	validation_0-mae:64.13661	validation_1-mae:64.95294
# [190]	validation_0-mae:63.85111	validation_1-mae:64.67048
# [191]	validation_0-mae:63.56505	validation_1-mae:64.38777
# [192]	validation_0-mae:63.28514	validation_1-mae:64.10885
# [193]	validation_0-mae:63.00722	validation_1-mae:63.83287
# [194]	validation_0-mae:62.73493	validation_1-mae:63.56215
# [195]	validation_0-mae:62.45879	validation_1-mae:63.28923
# [196]	validation_0-mae:62.18750	validation_1-mae:63.02090
# [197]	validation_0-mae:61.92355	validation_1-mae:62.75983
# [198]	validation_0-mae:61.66166	validation_1-mae:62.49991
# [199]	validation_0-mae:61.40454	validation_1-mae:62.24561
# [200]	validation_0-mae:61.14950	validation_1-mae:61.99410
# [201]	validation_0-mae:60.89834	validation_1-mae:61.74553
# [202]	validation_0-mae:60.65174	validation_1-mae:61.50268
# [203]	validation_0-mae:60.40510	validation_1-mae:61.25929
# [204]	validation_0-mae:60.16262	validation_1-mae:61.01916
# [205]	validation_0-mae:59.92741	validation_1-mae:60.78641
# [206]	validation_0-mae:59.69157	validation_1-mae:60.55343
# [207]	validation_0-mae:59.46253	validation_1-mae:60.32702
# [208]	validation_0-mae:59.23202	validation_1-mae:60.09921
# [209]	validation_0-mae:59.00832	validation_1-mae:59.87879
# [210]	validation_0-mae:58.78011	validation_1-mae:59.65343
# [211]	validation_0-mae:58.55834	validation_1-mae:59.43503
# [212]	validation_0-mae:58.33928	validation_1-mae:59.21950
# [213]	validation_0-mae:58.12288	validation_1-mae:59.00620
# [214]	validation_0-mae:57.91535	validation_1-mae:58.80015
# [215]	validation_0-mae:57.71202	validation_1-mae:58.59937
# [216]	validation_0-mae:57.50324	validation_1-mae:58.39350
# [217]	validation_0-mae:57.29903	validation_1-mae:58.19243
# [218]	validation_0-mae:57.09787	validation_1-mae:57.99393
# [219]	validation_0-mae:56.89903	validation_1-mae:57.79918
# [220]	validation_0-mae:56.70289	validation_1-mae:57.60530
# [221]	validation_0-mae:56.50925	validation_1-mae:57.41477
# [222]	validation_0-mae:56.31894	validation_1-mae:57.22759
# [223]	validation_0-mae:56.13075	validation_1-mae:57.04285
# [224]	validation_0-mae:55.94833	validation_1-mae:56.86229
# [225]	validation_0-mae:55.76681	validation_1-mae:56.68477
# [226]	validation_0-mae:55.57807	validation_1-mae:56.49900
# [227]	validation_0-mae:55.39369	validation_1-mae:56.31699
# [228]	validation_0-mae:55.21789	validation_1-mae:56.14412
# [229]	validation_0-mae:55.04228	validation_1-mae:55.97025
# [230]	validation_0-mae:54.87333	validation_1-mae:55.80434
# [231]	validation_0-mae:54.69620	validation_1-mae:55.62998
# [232]	validation_0-mae:54.52902	validation_1-mae:55.46721
# [233]	validation_0-mae:54.37189	validation_1-mae:55.31345
# [234]	validation_0-mae:54.20996	validation_1-mae:55.15442
# [235]	validation_0-mae:54.05422	validation_1-mae:55.00083
# [236]	validation_0-mae:53.89463	validation_1-mae:54.84391
# [237]	validation_0-mae:53.74351	validation_1-mae:54.69509
# [238]	validation_0-mae:53.59117	validation_1-mae:54.54581
# [239]	validation_0-mae:53.43792	validation_1-mae:54.39578
# [240]	validation_0-mae:53.28919	validation_1-mae:54.24933
# [241]	validation_0-mae:53.14348	validation_1-mae:54.10627
# [242]	validation_0-mae:52.99915	validation_1-mae:53.96514
# [243]	validation_0-mae:52.86021	validation_1-mae:53.82943
# [244]	validation_0-mae:52.71554	validation_1-mae:53.68743
# [245]	validation_0-mae:52.57193	validation_1-mae:53.54555
# [246]	validation_0-mae:52.43663	validation_1-mae:53.41287
# [247]	validation_0-mae:52.30011	validation_1-mae:53.27857
# [248]	validation_0-mae:52.16727	validation_1-mae:53.14877
# [249]	validation_0-mae:52.03397	validation_1-mae:53.01795
# [250]	validation_0-mae:51.89877	validation_1-mae:52.88515
# [251]	validation_0-mae:51.77086	validation_1-mae:52.75903
# [252]	validation_0-mae:51.64860	validation_1-mae:52.64036
# [253]	validation_0-mae:51.51784	validation_1-mae:52.51202
# [254]	validation_0-mae:51.39359	validation_1-mae:52.38990
# [255]	validation_0-mae:51.27118	validation_1-mae:52.27072
# [256]	validation_0-mae:51.14489	validation_1-mae:52.14734
# [257]	validation_0-mae:51.02440	validation_1-mae:52.03031
# [258]	validation_0-mae:50.91154	validation_1-mae:51.92089
# [259]	validation_0-mae:50.80056	validation_1-mae:51.81324
# [260]	validation_0-mae:50.68505	validation_1-mae:51.70126
# [261]	validation_0-mae:50.56966	validation_1-mae:51.58876
# [262]	validation_0-mae:50.44933	validation_1-mae:51.47240
# [263]	validation_0-mae:50.33286	validation_1-mae:51.35831
# [264]	validation_0-mae:50.22436	validation_1-mae:51.25242
# [265]	validation_0-mae:50.11512	validation_1-mae:51.14667
# [266]	validation_0-mae:50.00082	validation_1-mae:51.03715
# [267]	validation_0-mae:49.89682	validation_1-mae:50.93632
# [268]	validation_0-mae:49.79049	validation_1-mae:50.83251
# [269]	validation_0-mae:49.68845	validation_1-mae:50.73386
# [270]	validation_0-mae:49.58825	validation_1-mae:50.63695
# [271]	validation_0-mae:49.49019	validation_1-mae:50.54246
# [272]	validation_0-mae:49.39349	validation_1-mae:50.44891
# [273]	validation_0-mae:49.29450	validation_1-mae:50.35308
# [274]	validation_0-mae:49.19177	validation_1-mae:50.25218
# [275]	validation_0-mae:49.09237	validation_1-mae:50.15563
# [276]	validation_0-mae:48.99437	validation_1-mae:50.06124
# [277]	validation_0-mae:48.90241	validation_1-mae:49.97218
# [278]	validation_0-mae:48.81272	validation_1-mae:49.88563
# [279]	validation_0-mae:48.71758	validation_1-mae:49.79302
# [280]	validation_0-mae:48.62744	validation_1-mae:49.70620
# [281]	validation_0-mae:48.53547	validation_1-mae:49.61746
# [282]	validation_0-mae:48.45083	validation_1-mae:49.53624
# [283]	validation_0-mae:48.35724	validation_1-mae:49.44680
# [284]	validation_0-mae:48.26999	validation_1-mae:49.36251
# [285]	validation_0-mae:48.18544	validation_1-mae:49.28082
# [286]	validation_0-mae:48.10150	validation_1-mae:49.19973
# [287]	validation_0-mae:48.01585	validation_1-mae:49.11642
# [288]	validation_0-mae:47.93380	validation_1-mae:49.03819
# [289]	validation_0-mae:47.85421	validation_1-mae:48.96200
# [290]	validation_0-mae:47.77534	validation_1-mae:48.88687
# [291]	validation_0-mae:47.70146	validation_1-mae:48.81586
# [292]	validation_0-mae:47.62393	validation_1-mae:48.74197
# [293]	validation_0-mae:47.54831	validation_1-mae:48.66972
# [294]	validation_0-mae:47.47397	validation_1-mae:48.59811
# [295]	validation_0-mae:47.39317	validation_1-mae:48.52100
# [296]	validation_0-mae:47.32317	validation_1-mae:48.45457
# [297]	validation_0-mae:47.24738	validation_1-mae:48.38149
# [298]	validation_0-mae:47.18091	validation_1-mae:48.31812
# [299]	validation_0-mae:47.10998	validation_1-mae:48.25013
# [300]	validation_0-mae:47.04393	validation_1-mae:48.18622
# [301]	validation_0-mae:46.97408	validation_1-mae:48.12029
# [302]	validation_0-mae:46.91081	validation_1-mae:48.05924
# [303]	validation_0-mae:46.83789	validation_1-mae:47.98917
# [304]	validation_0-mae:46.77000	validation_1-mae:47.92354
# [305]	validation_0-mae:46.70559	validation_1-mae:47.86101
# [306]	validation_0-mae:46.64317	validation_1-mae:47.80198
# [307]	validation_0-mae:46.57561	validation_1-mae:47.73734
# [308]	validation_0-mae:46.51328	validation_1-mae:47.67640
# [309]	validation_0-mae:46.45261	validation_1-mae:47.61831
# [310]	validation_0-mae:46.39171	validation_1-mae:47.56025
# [311]	validation_0-mae:46.32453	validation_1-mae:47.49510
# [312]	validation_0-mae:46.26132	validation_1-mae:47.43483
# [313]	validation_0-mae:46.19826	validation_1-mae:47.37452
# [314]	validation_0-mae:46.14018	validation_1-mae:47.31989
# [315]	validation_0-mae:46.07913	validation_1-mae:47.26153
# [316]	validation_0-mae:46.01983	validation_1-mae:47.20404
# [317]	validation_0-mae:45.96201	validation_1-mae:47.14917
# [318]	validation_0-mae:45.91180	validation_1-mae:47.10046
# [319]	validation_0-mae:45.84834	validation_1-mae:47.03992
# [320]	validation_0-mae:45.79192	validation_1-mae:46.98547
# [321]	validation_0-mae:45.74356	validation_1-mae:46.93804
# [322]	validation_0-mae:45.68884	validation_1-mae:46.88597
# [323]	validation_0-mae:45.63605	validation_1-mae:46.83561
# [324]	validation_0-mae:45.57771	validation_1-mae:46.78030
# [325]	validation_0-mae:45.53058	validation_1-mae:46.73542
# [326]	validation_0-mae:45.47573	validation_1-mae:46.68362
# [327]	validation_0-mae:45.42290	validation_1-mae:46.63308
# [328]	validation_0-mae:45.37322	validation_1-mae:46.58452
# [329]	validation_0-mae:45.32694	validation_1-mae:46.54013
# [330]	validation_0-mae:45.26979	validation_1-mae:46.48568
# [331]	validation_0-mae:45.21881	validation_1-mae:46.43675
# [332]	validation_0-mae:45.16738	validation_1-mae:46.38749
# [333]	validation_0-mae:45.11835	validation_1-mae:46.34135
# [334]	validation_0-mae:45.07055	validation_1-mae:46.29589
# [335]	validation_0-mae:45.01933	validation_1-mae:46.24738
# [336]	validation_0-mae:44.97638	validation_1-mae:46.20613
# [337]	validation_0-mae:44.93103	validation_1-mae:46.16318
# [338]	validation_0-mae:44.88205	validation_1-mae:46.11700
# [339]	validation_0-mae:44.83859	validation_1-mae:46.07651
# [340]	validation_0-mae:44.79785	validation_1-mae:46.03854
# [341]	validation_0-mae:44.75186	validation_1-mae:45.99471
# [342]	validation_0-mae:44.70707	validation_1-mae:45.95263
# [343]	validation_0-mae:44.66871	validation_1-mae:45.91650
# [344]	validation_0-mae:44.62806	validation_1-mae:45.87716
# [345]	validation_0-mae:44.59004	validation_1-mae:45.84181
# [346]	validation_0-mae:44.55111	validation_1-mae:45.80563
# [347]	validation_0-mae:44.51179	validation_1-mae:45.76778
# [348]	validation_0-mae:44.47593	validation_1-mae:45.73273
# [349]	validation_0-mae:44.43753	validation_1-mae:45.69602
# [350]	validation_0-mae:44.40326	validation_1-mae:45.66322
# [351]	validation_0-mae:44.36428	validation_1-mae:45.62714
# [352]	validation_0-mae:44.32609	validation_1-mae:45.59192
# [353]	validation_0-mae:44.28814	validation_1-mae:45.55684
# [354]	validation_0-mae:44.23496	validation_1-mae:45.50632
# [355]	validation_0-mae:44.20127	validation_1-mae:45.47527
# [356]	validation_0-mae:44.16435	validation_1-mae:45.44076
# [357]	validation_0-mae:44.13070	validation_1-mae:45.40840
# [358]	validation_0-mae:44.09212	validation_1-mae:45.37304
# [359]	validation_0-mae:44.05828	validation_1-mae:45.34155
# [360]	validation_0-mae:44.01635	validation_1-mae:45.30021
# [361]	validation_0-mae:43.98093	validation_1-mae:45.26719
# [362]	validation_0-mae:43.93911	validation_1-mae:45.22744
# [363]	validation_0-mae:43.90978	validation_1-mae:45.20026
# [364]	validation_0-mae:43.87451	validation_1-mae:45.16698
# [365]	validation_0-mae:43.83618	validation_1-mae:45.13105
# [366]	validation_0-mae:43.80226	validation_1-mae:45.10034
# [367]	validation_0-mae:43.77129	validation_1-mae:45.07177
# [368]	validation_0-mae:43.73242	validation_1-mae:45.03477
# [369]	validation_0-mae:43.70147	validation_1-mae:45.00598
# [370]	validation_0-mae:43.66228	validation_1-mae:44.96864
# [371]	validation_0-mae:43.62731	validation_1-mae:44.93566
# [372]	validation_0-mae:43.59286	validation_1-mae:44.90435
# [373]	validation_0-mae:43.55478	validation_1-mae:44.86848
# [374]	validation_0-mae:43.52576	validation_1-mae:44.84161
# [375]	validation_0-mae:43.49555	validation_1-mae:44.81313
# [376]	validation_0-mae:43.46576	validation_1-mae:44.78464
# [377]	validation_0-mae:43.43647	validation_1-mae:44.75754
# [378]	validation_0-mae:43.40368	validation_1-mae:44.72683
# [379]	validation_0-mae:43.37212	validation_1-mae:44.69748
# [380]	validation_0-mae:43.34291	validation_1-mae:44.67012
# [381]	validation_0-mae:43.31664	validation_1-mae:44.64537
# [382]	validation_0-mae:43.28859	validation_1-mae:44.61893
# [383]	validation_0-mae:43.26008	validation_1-mae:44.59308
# [384]	validation_0-mae:43.23370	validation_1-mae:44.56868
# [385]	validation_0-mae:43.20757	validation_1-mae:44.54442
# [386]	validation_0-mae:43.17941	validation_1-mae:44.51833
# [387]	validation_0-mae:43.15289	validation_1-mae:44.49329
# [388]	validation_0-mae:43.11680	validation_1-mae:44.46030
# [389]	validation_0-mae:43.08974	validation_1-mae:44.43593
# [390]	validation_0-mae:43.06440	validation_1-mae:44.41386
# [391]	validation_0-mae:43.03480	validation_1-mae:44.38671
# [392]	validation_0-mae:43.00916	validation_1-mae:44.36350
# [393]	validation_0-mae:42.98309	validation_1-mae:44.33954
# [394]	validation_0-mae:42.95747	validation_1-mae:44.31658
# [395]	validation_0-mae:42.93316	validation_1-mae:44.29406
# [396]	validation_0-mae:42.90254	validation_1-mae:44.26565
# [397]	validation_0-mae:42.87857	validation_1-mae:44.24438
# [398]	validation_0-mae:42.85545	validation_1-mae:44.22307
# [399]	validation_0-mae:42.82302	validation_1-mae:44.19185
# [400]	validation_0-mae:42.79918	validation_1-mae:44.17007
# [401]	validation_0-mae:42.77295	validation_1-mae:44.14572
# [402]	validation_0-mae:42.74375	validation_1-mae:44.11841
# [403]	validation_0-mae:42.70785	validation_1-mae:44.08493
# [404]	validation_0-mae:42.68631	validation_1-mae:44.06559
# [405]	validation_0-mae:42.65081	validation_1-mae:44.03266
# [406]	validation_0-mae:42.62332	validation_1-mae:44.00593
# [407]	validation_0-mae:42.58744	validation_1-mae:43.97142
# [408]	validation_0-mae:42.54863	validation_1-mae:43.93436
# [409]	validation_0-mae:42.51324	validation_1-mae:43.90137
# [410]	validation_0-mae:42.48965	validation_1-mae:43.87963
# [411]	validation_0-mae:42.45838	validation_1-mae:43.84942
# [412]	validation_0-mae:42.42721	validation_1-mae:43.82030
# [413]	validation_0-mae:42.39953	validation_1-mae:43.79416
# [414]	validation_0-mae:42.37305	validation_1-mae:43.76987
# [415]	validation_0-mae:42.35121	validation_1-mae:43.74919
# [416]	validation_0-mae:42.31752	validation_1-mae:43.71796
# [417]	validation_0-mae:42.29857	validation_1-mae:43.70107
# [418]	validation_0-mae:42.27157	validation_1-mae:43.67544
# [419]	validation_0-mae:42.24762	validation_1-mae:43.65300
# [420]	validation_0-mae:42.21648	validation_1-mae:43.62309
# [421]	validation_0-mae:42.18804	validation_1-mae:43.59712
# [422]	validation_0-mae:42.15693	validation_1-mae:43.56743
# [423]	validation_0-mae:42.13430	validation_1-mae:43.54632
# [424]	validation_0-mae:42.10705	validation_1-mae:43.52032
# [425]	validation_0-mae:42.08009	validation_1-mae:43.49496
# [426]	validation_0-mae:42.05074	validation_1-mae:43.46779
# [427]	validation_0-mae:42.02582	validation_1-mae:43.44469
# [428]	validation_0-mae:41.99441	validation_1-mae:43.41485
# [429]	validation_0-mae:41.97779	validation_1-mae:43.40004
# [430]	validation_0-mae:41.95008	validation_1-mae:43.37462
# [431]	validation_0-mae:41.91715	validation_1-mae:43.34404
# [432]	validation_0-mae:41.89434	validation_1-mae:43.32295
# [433]	validation_0-mae:41.87644	validation_1-mae:43.30803
# [434]	validation_0-mae:41.85285	validation_1-mae:43.28547
# [435]	validation_0-mae:41.82645	validation_1-mae:43.26051
# [436]	validation_0-mae:41.81088	validation_1-mae:43.24698
# [437]	validation_0-mae:41.79001	validation_1-mae:43.22714
# [438]	validation_0-mae:41.76634	validation_1-mae:43.20454
# [439]	validation_0-mae:41.74044	validation_1-mae:43.17960
# [440]	validation_0-mae:41.71538	validation_1-mae:43.15636
# [441]	validation_0-mae:41.68944	validation_1-mae:43.13151
# [442]	validation_0-mae:41.66381	validation_1-mae:43.10771
# [443]	validation_0-mae:41.64335	validation_1-mae:43.08777
# [444]	validation_0-mae:41.61815	validation_1-mae:43.06409
# [445]	validation_0-mae:41.59240	validation_1-mae:43.03957
# [446]	validation_0-mae:41.56779	validation_1-mae:43.01625
# [447]	validation_0-mae:41.54397	validation_1-mae:42.99415
# [448]	validation_0-mae:41.51869	validation_1-mae:42.96999
# [449]	validation_0-mae:41.49557	validation_1-mae:42.94840
# [450]	validation_0-mae:41.47752	validation_1-mae:42.93293
# [451]	validation_0-mae:41.45446	validation_1-mae:42.91087
# [452]	validation_0-mae:41.43889	validation_1-mae:42.89737
# [453]	validation_0-mae:41.41756	validation_1-mae:42.87772
# [454]	validation_0-mae:41.40514	validation_1-mae:42.86716
# [455]	validation_0-mae:41.38647	validation_1-mae:42.84955
# [456]	validation_0-mae:41.36092	validation_1-mae:42.82495
# [457]	validation_0-mae:41.33917	validation_1-mae:42.80431
# [458]	validation_0-mae:41.31370	validation_1-mae:42.78024
# [459]	validation_0-mae:41.28644	validation_1-mae:42.75463
# [460]	validation_0-mae:41.26427	validation_1-mae:42.73365
# [461]	validation_0-mae:41.24568	validation_1-mae:42.71669
# [462]	validation_0-mae:41.22531	validation_1-mae:42.69799
# [463]	validation_0-mae:41.20566	validation_1-mae:42.67934
# [464]	validation_0-mae:41.18438	validation_1-mae:42.65923
# [465]	validation_0-mae:41.16531	validation_1-mae:42.64131
# [466]	validation_0-mae:41.14450	validation_1-mae:42.62286
# [467]	validation_0-mae:41.12046	validation_1-mae:42.60104
# [468]	validation_0-mae:41.10125	validation_1-mae:42.58435
# [469]	validation_0-mae:41.08722	validation_1-mae:42.57205
# [470]	validation_0-mae:41.06410	validation_1-mae:42.55199
# [471]	validation_0-mae:41.04741	validation_1-mae:42.53621
# [472]	validation_0-mae:41.02990	validation_1-mae:42.52074
# [473]	validation_0-mae:41.01379	validation_1-mae:42.50534
# [474]	validation_0-mae:40.99549	validation_1-mae:42.48981
# [475]	validation_0-mae:40.97855	validation_1-mae:42.47426
# [476]	validation_0-mae:40.96407	validation_1-mae:42.46180
# [477]	validation_0-mae:40.94948	validation_1-mae:42.44926
# [478]	validation_0-mae:40.93640	validation_1-mae:42.43761
# [479]	validation_0-mae:40.92038	validation_1-mae:42.42310
# [480]	validation_0-mae:40.91013	validation_1-mae:42.41440
# [481]	validation_0-mae:40.89467	validation_1-mae:42.40055
# [482]	validation_0-mae:40.88061	validation_1-mae:42.38797
# [483]	validation_0-mae:40.85995	validation_1-mae:42.36830
# [484]	validation_0-mae:40.84723	validation_1-mae:42.35792
# [485]	validation_0-mae:40.82857	validation_1-mae:42.34148
# [486]	validation_0-mae:40.81064	validation_1-mae:42.32561
# [487]	validation_0-mae:40.79410	validation_1-mae:42.31107
# [488]	validation_0-mae:40.77992	validation_1-mae:42.29836
# [489]	validation_0-mae:40.77052	validation_1-mae:42.29017
# [490]	validation_0-mae:40.76129	validation_1-mae:42.28290
# [491]	validation_0-mae:40.74821	validation_1-mae:42.27170
# [492]	validation_0-mae:40.73097	validation_1-mae:42.25647
# [493]	validation_0-mae:40.72026	validation_1-mae:42.24676
# [494]	validation_0-mae:40.70407	validation_1-mae:42.23267
# [495]	validation_0-mae:40.69199	validation_1-mae:42.22130
# [496]	validation_0-mae:40.68069	validation_1-mae:42.21112
# [497]	validation_0-mae:40.66787	validation_1-mae:42.19985
# [498]	validation_0-mae:40.64926	validation_1-mae:42.18340
# [499]	validation_0-mae:40.63661	validation_1-mae:42.17176
# [500]	validation_0-mae:40.62344	validation_1-mae:42.16049
# [501]	validation_0-mae:40.61059	validation_1-mae:42.14857
# [502]	validation_0-mae:40.59972	validation_1-mae:42.13864
# [503]	validation_0-mae:40.58337	validation_1-mae:42.12414
# [504]	validation_0-mae:40.56820	validation_1-mae:42.10995
# [505]	validation_0-mae:40.55418	validation_1-mae:42.09780
# [506]	validation_0-mae:40.53686	validation_1-mae:42.08293
# [507]	validation_0-mae:40.52637	validation_1-mae:42.07318
# [508]	validation_0-mae:40.51510	validation_1-mae:42.06252
# [509]	validation_0-mae:40.50218	validation_1-mae:42.05147
# [510]	validation_0-mae:40.49123	validation_1-mae:42.04241
# [511]	validation_0-mae:40.46975	validation_1-mae:42.02375
# [512]	validation_0-mae:40.45485	validation_1-mae:42.01061
# [513]	validation_0-mae:40.44118	validation_1-mae:41.99754
# [514]	validation_0-mae:40.42563	validation_1-mae:41.98465
# [515]	validation_0-mae:40.40464	validation_1-mae:41.96585
# [516]	validation_0-mae:40.38684	validation_1-mae:41.94907
# [517]	validation_0-mae:40.37428	validation_1-mae:41.93773
# [518]	validation_0-mae:40.35770	validation_1-mae:41.92286
# [519]	validation_0-mae:40.33976	validation_1-mae:41.90791
# [520]	validation_0-mae:40.33001	validation_1-mae:41.89910
# [521]	validation_0-mae:40.31389	validation_1-mae:41.88496
# [522]	validation_0-mae:40.29331	validation_1-mae:41.86660
# [523]	validation_0-mae:40.27899	validation_1-mae:41.85378
# [524]	validation_0-mae:40.26912	validation_1-mae:41.84495
# [525]	validation_0-mae:40.26044	validation_1-mae:41.83773
# [526]	validation_0-mae:40.24772	validation_1-mae:41.82675
# [527]	validation_0-mae:40.23355	validation_1-mae:41.81391
# [528]	validation_0-mae:40.22000	validation_1-mae:41.80220
# [529]	validation_0-mae:40.20328	validation_1-mae:41.78670
# [530]	validation_0-mae:40.19389	validation_1-mae:41.77886
# [531]	validation_0-mae:40.18205	validation_1-mae:41.76891
# [532]	validation_0-mae:40.16956	validation_1-mae:41.75845
# [533]	validation_0-mae:40.15581	validation_1-mae:41.74633
# [534]	validation_0-mae:40.14180	validation_1-mae:41.73549
# [535]	validation_0-mae:40.12103	validation_1-mae:41.71655
# [536]	validation_0-mae:40.10900	validation_1-mae:41.70591
# [537]	validation_0-mae:40.09245	validation_1-mae:41.69005
# [538]	validation_0-mae:40.08105	validation_1-mae:41.67998
# [539]	validation_0-mae:40.06826	validation_1-mae:41.66982
# [540]	validation_0-mae:40.05960	validation_1-mae:41.66225
# [541]	validation_0-mae:40.05075	validation_1-mae:41.65377
# [542]	validation_0-mae:40.03922	validation_1-mae:41.64389
# [543]	validation_0-mae:40.02479	validation_1-mae:41.63139
# [544]	validation_0-mae:40.01252	validation_1-mae:41.62080
# [545]	validation_0-mae:39.99913	validation_1-mae:41.60901
# [546]	validation_0-mae:39.98940	validation_1-mae:41.60132
# [547]	validation_0-mae:39.98086	validation_1-mae:41.59378
# [548]	validation_0-mae:39.96874	validation_1-mae:41.58396
# [549]	validation_0-mae:39.95719	validation_1-mae:41.57467
# [550]	validation_0-mae:39.94382	validation_1-mae:41.56306
# [551]	validation_0-mae:39.93409	validation_1-mae:41.55569
# [552]	validation_0-mae:39.92329	validation_1-mae:41.54657
# [553]	validation_0-mae:39.91255	validation_1-mae:41.53723
# [554]	validation_0-mae:39.90216	validation_1-mae:41.52778
# [555]	validation_0-mae:39.89141	validation_1-mae:41.51823
# [556]	validation_0-mae:39.87405	validation_1-mae:41.50319
# [557]	validation_0-mae:39.85971	validation_1-mae:41.49001
# [558]	validation_0-mae:39.84627	validation_1-mae:41.47826
# [559]	validation_0-mae:39.83495	validation_1-mae:41.46939
# [560]	validation_0-mae:39.82277	validation_1-mae:41.45941
# [561]	validation_0-mae:39.81111	validation_1-mae:41.45011
# [562]	validation_0-mae:39.79157	validation_1-mae:41.43237
# [563]	validation_0-mae:39.77949	validation_1-mae:41.42117
# [564]	validation_0-mae:39.77089	validation_1-mae:41.41369
# [565]	validation_0-mae:39.75599	validation_1-mae:41.40071
# [566]	validation_0-mae:39.74740	validation_1-mae:41.39302
# [567]	validation_0-mae:39.73534	validation_1-mae:41.38245
# [568]	validation_0-mae:39.72668	validation_1-mae:41.37561
# [569]	validation_0-mae:39.71343	validation_1-mae:41.36519
# [570]	validation_0-mae:39.70195	validation_1-mae:41.35606
# [571]	validation_0-mae:39.69372	validation_1-mae:41.34952
# [572]	validation_0-mae:39.68398	validation_1-mae:41.34089
# [573]	validation_0-mae:39.67316	validation_1-mae:41.33103
# [574]	validation_0-mae:39.66134	validation_1-mae:41.32000
# [575]	validation_0-mae:39.65020	validation_1-mae:41.31071
# [576]	validation_0-mae:39.63817	validation_1-mae:41.30042
# [577]	validation_0-mae:39.63431	validation_1-mae:41.29789
# [578]	validation_0-mae:39.62491	validation_1-mae:41.29003
# [579]	validation_0-mae:39.61666	validation_1-mae:41.28344
# [580]	validation_0-mae:39.60964	validation_1-mae:41.27750
# [581]	validation_0-mae:39.60134	validation_1-mae:41.27110
# [582]	validation_0-mae:39.59086	validation_1-mae:41.26210
# [583]	validation_0-mae:39.58273	validation_1-mae:41.25596
# [584]	validation_0-mae:39.57679	validation_1-mae:41.25110
# [585]	validation_0-mae:39.57073	validation_1-mae:41.24602
# [586]	validation_0-mae:39.55993	validation_1-mae:41.23699
# [587]	validation_0-mae:39.55028	validation_1-mae:41.22924
# [588]	validation_0-mae:39.54021	validation_1-mae:41.22111
# [589]	validation_0-mae:39.53337	validation_1-mae:41.21616
# [590]	validation_0-mae:39.52390	validation_1-mae:41.20812
# [591]	validation_0-mae:39.51901	validation_1-mae:41.20436
# [592]	validation_0-mae:39.51136	validation_1-mae:41.19857
# [593]	validation_0-mae:39.50184	validation_1-mae:41.19075
# [594]	validation_0-mae:39.49710	validation_1-mae:41.18758
# [595]	validation_0-mae:39.49016	validation_1-mae:41.18217
# [596]	validation_0-mae:39.48139	validation_1-mae:41.17499
# [597]	validation_0-mae:39.47406	validation_1-mae:41.16914
# [598]	validation_0-mae:39.46775	validation_1-mae:41.16459
# [599]	validation_0-mae:39.45908	validation_1-mae:41.15646
# [600]	validation_0-mae:39.45214	validation_1-mae:41.15057
# [601]	validation_0-mae:39.44375	validation_1-mae:41.14429
# [602]	validation_0-mae:39.43411	validation_1-mae:41.13642
# [603]	validation_0-mae:39.42926	validation_1-mae:41.13351
# [604]	validation_0-mae:39.41991	validation_1-mae:41.12625
# [605]	validation_0-mae:39.41145	validation_1-mae:41.11939
# [606]	validation_0-mae:39.40535	validation_1-mae:41.11457
# [607]	validation_0-mae:39.39910	validation_1-mae:41.11085
# [608]	validation_0-mae:39.39179	validation_1-mae:41.10547
# [609]	validation_0-mae:39.38365	validation_1-mae:41.09879
# [610]	validation_0-mae:39.37926	validation_1-mae:41.09622
# [611]	validation_0-mae:39.37284	validation_1-mae:41.09190
# [612]	validation_0-mae:39.36718	validation_1-mae:41.08753
# [613]	validation_0-mae:39.36120	validation_1-mae:41.08350
# [614]	validation_0-mae:39.35767	validation_1-mae:41.08066
# [615]	validation_0-mae:39.35324	validation_1-mae:41.07798
# [616]	validation_0-mae:39.34548	validation_1-mae:41.07116
# [617]	validation_0-mae:39.33810	validation_1-mae:41.06586
# [618]	validation_0-mae:39.33443	validation_1-mae:41.06363
# [619]	validation_0-mae:39.32665	validation_1-mae:41.05654
# [620]	validation_0-mae:39.32171	validation_1-mae:41.05346
# [621]	validation_0-mae:39.30986	validation_1-mae:41.04294
# [622]	validation_0-mae:39.30645	validation_1-mae:41.04128
# [623]	validation_0-mae:39.29913	validation_1-mae:41.03433
# [624]	validation_0-mae:39.29601	validation_1-mae:41.03256
# [625]	validation_0-mae:39.29000	validation_1-mae:41.02749
# [626]	validation_0-mae:39.28371	validation_1-mae:41.02287
# [627]	validation_0-mae:39.27485	validation_1-mae:41.01469
# [628]	validation_0-mae:39.27137	validation_1-mae:41.01241
# [629]	validation_0-mae:39.26248	validation_1-mae:41.00403
# [630]	validation_0-mae:39.25869	validation_1-mae:41.00080
# [631]	validation_0-mae:39.24937	validation_1-mae:40.99295
# [632]	validation_0-mae:39.24238	validation_1-mae:40.98825
# [633]	validation_0-mae:39.23715	validation_1-mae:40.98456
# [634]	validation_0-mae:39.22818	validation_1-mae:40.97720
# [635]	validation_0-mae:39.22237	validation_1-mae:40.97286
# [636]	validation_0-mae:39.21789	validation_1-mae:40.96951
# [637]	validation_0-mae:39.20584	validation_1-mae:40.95914
# [638]	validation_0-mae:39.20067	validation_1-mae:40.95512
# [639]	validation_0-mae:39.19140	validation_1-mae:40.94728
# [640]	validation_0-mae:39.18595	validation_1-mae:40.94348
# [641]	validation_0-mae:39.17669	validation_1-mae:40.93505
# [642]	validation_0-mae:39.17333	validation_1-mae:40.93272
# [643]	validation_0-mae:39.16461	validation_1-mae:40.92593
# [644]	validation_0-mae:39.16022	validation_1-mae:40.92268
# [645]	validation_0-mae:39.14931	validation_1-mae:40.91264
# [646]	validation_0-mae:39.14357	validation_1-mae:40.90895
# [647]	validation_0-mae:39.13830	validation_1-mae:40.90521
# [648]	validation_0-mae:39.13411	validation_1-mae:40.90269
# [649]	validation_0-mae:39.12759	validation_1-mae:40.89730
# [650]	validation_0-mae:39.12339	validation_1-mae:40.89515
# [651]	validation_0-mae:39.11845	validation_1-mae:40.89193
# [652]	validation_0-mae:39.11189	validation_1-mae:40.88740
# [653]	validation_0-mae:39.10841	validation_1-mae:40.88555
# [654]	validation_0-mae:39.10301	validation_1-mae:40.88076
# [655]	validation_0-mae:39.09664	validation_1-mae:40.87525
# [656]	validation_0-mae:39.09047	validation_1-mae:40.87017
# [657]	validation_0-mae:39.07890	validation_1-mae:40.86104
# [658]	validation_0-mae:39.07423	validation_1-mae:40.85803
# [659]	validation_0-mae:39.06528	validation_1-mae:40.85119
# [660]	validation_0-mae:39.06190	validation_1-mae:40.84904
# [661]	validation_0-mae:39.05171	validation_1-mae:40.84016
# [662]	validation_0-mae:39.04879	validation_1-mae:40.83857
# [663]	validation_0-mae:39.03693	validation_1-mae:40.82809
# [664]	validation_0-mae:39.03281	validation_1-mae:40.82492
# [665]	validation_0-mae:39.02937	validation_1-mae:40.82293
# [666]	validation_0-mae:39.02386	validation_1-mae:40.81911
# [667]	validation_0-mae:39.01934	validation_1-mae:40.81592
# [668]	validation_0-mae:39.01464	validation_1-mae:40.81264
# [669]	validation_0-mae:39.00992	validation_1-mae:40.80878
# [670]	validation_0-mae:39.00051	validation_1-mae:40.80084
# [671]	validation_0-mae:38.99540	validation_1-mae:40.79684
# [672]	validation_0-mae:38.99140	validation_1-mae:40.79408
# [673]	validation_0-mae:38.98801	validation_1-mae:40.79206
# [674]	validation_0-mae:38.98233	validation_1-mae:40.78753
# [675]	validation_0-mae:38.97704	validation_1-mae:40.78389
# [676]	validation_0-mae:38.97393	validation_1-mae:40.78258
# [677]	validation_0-mae:38.96797	validation_1-mae:40.77760
# [678]	validation_0-mae:38.95909	validation_1-mae:40.77038
# [679]	validation_0-mae:38.95452	validation_1-mae:40.76734
# [680]	validation_0-mae:38.94308	validation_1-mae:40.75706
# [681]	validation_0-mae:38.93349	validation_1-mae:40.74921
# [682]	validation_0-mae:38.93064	validation_1-mae:40.74742
# [683]	validation_0-mae:38.92604	validation_1-mae:40.74360
# [684]	validation_0-mae:38.91681	validation_1-mae:40.73561
# [685]	validation_0-mae:38.91427	validation_1-mae:40.73429
# [686]	validation_0-mae:38.90995	validation_1-mae:40.73135
# [687]	validation_0-mae:38.90454	validation_1-mae:40.72729
# [688]	validation_0-mae:38.89617	validation_1-mae:40.72009
# [689]	validation_0-mae:38.89193	validation_1-mae:40.71721
# [690]	validation_0-mae:38.88652	validation_1-mae:40.71231
# [691]	validation_0-mae:38.88220	validation_1-mae:40.70873
# [692]	validation_0-mae:38.87545	validation_1-mae:40.70336
# [693]	validation_0-mae:38.87076	validation_1-mae:40.69987
# [694]	validation_0-mae:38.86636	validation_1-mae:40.69697
# [695]	validation_0-mae:38.86271	validation_1-mae:40.69528
# [696]	validation_0-mae:38.85729	validation_1-mae:40.69121
# [697]	validation_0-mae:38.85218	validation_1-mae:40.68756
# [698]	validation_0-mae:38.84846	validation_1-mae:40.68514
# [699]	validation_0-mae:38.83983	validation_1-mae:40.67776
# [700]	validation_0-mae:38.83271	validation_1-mae:40.67169
# [701]	validation_0-mae:38.82707	validation_1-mae:40.66715
# [702]	validation_0-mae:38.82381	validation_1-mae:40.66505
# [703]	validation_0-mae:38.81440	validation_1-mae:40.65696
# [704]	validation_0-mae:38.81009	validation_1-mae:40.65366
# [705]	validation_0-mae:38.80594	validation_1-mae:40.65062
# [706]	validation_0-mae:38.80145	validation_1-mae:40.64729
# [707]	validation_0-mae:38.79753	validation_1-mae:40.64472
# [708]	validation_0-mae:38.79190	validation_1-mae:40.64081
# [709]	validation_0-mae:38.78792	validation_1-mae:40.63802
# [710]	validation_0-mae:38.77819	validation_1-mae:40.62991
# [711]	validation_0-mae:38.77269	validation_1-mae:40.62525
# [712]	validation_0-mae:38.76842	validation_1-mae:40.62247
# [713]	validation_0-mae:38.76384	validation_1-mae:40.62013
# [714]	validation_0-mae:38.75754	validation_1-mae:40.61530
# [715]	validation_0-mae:38.74507	validation_1-mae:40.60383
# [716]	validation_0-mae:38.74020	validation_1-mae:40.60024
# [717]	validation_0-mae:38.73711	validation_1-mae:40.59860
# [718]	validation_0-mae:38.73355	validation_1-mae:40.59611
# [719]	validation_0-mae:38.72859	validation_1-mae:40.59221
# [720]	validation_0-mae:38.72390	validation_1-mae:40.58936
# [721]	validation_0-mae:38.71951	validation_1-mae:40.58655
# [722]	validation_0-mae:38.71253	validation_1-mae:40.58124
# [723]	validation_0-mae:38.70704	validation_1-mae:40.57584
# [724]	validation_0-mae:38.70100	validation_1-mae:40.57122
# [725]	validation_0-mae:38.68973	validation_1-mae:40.56055
# [726]	validation_0-mae:38.67958	validation_1-mae:40.55157
# [727]	validation_0-mae:38.67713	validation_1-mae:40.55030
# [728]	validation_0-mae:38.67002	validation_1-mae:40.54401
# [729]	validation_0-mae:38.66569	validation_1-mae:40.54089
# [730]	validation_0-mae:38.66031	validation_1-mae:40.53626
# [731]	validation_0-mae:38.65314	validation_1-mae:40.53123
# [732]	validation_0-mae:38.64992	validation_1-mae:40.52943
# [733]	validation_0-mae:38.64365	validation_1-mae:40.52565
# [734]	validation_0-mae:38.63273	validation_1-mae:40.51585
# [735]	validation_0-mae:38.62324	validation_1-mae:40.50727
# [736]	validation_0-mae:38.61888	validation_1-mae:40.50403
# [737]	validation_0-mae:38.61234	validation_1-mae:40.49885
# [738]	validation_0-mae:38.60493	validation_1-mae:40.49273
# [739]	validation_0-mae:38.59662	validation_1-mae:40.48513
# [740]	validation_0-mae:38.59183	validation_1-mae:40.48233
# [741]	validation_0-mae:38.58751	validation_1-mae:40.47938
# [742]	validation_0-mae:38.58022	validation_1-mae:40.47331
# [743]	validation_0-mae:38.57391	validation_1-mae:40.46892
# [744]	validation_0-mae:38.56692	validation_1-mae:40.46300
# [745]	validation_0-mae:38.56304	validation_1-mae:40.46078
# [746]	validation_0-mae:38.55886	validation_1-mae:40.45768
# [747]	validation_0-mae:38.55363	validation_1-mae:40.45361
# [748]	validation_0-mae:38.54398	validation_1-mae:40.44511
# [749]	validation_0-mae:38.53787	validation_1-mae:40.44033
# [750]	validation_0-mae:38.53318	validation_1-mae:40.43605
# [751]	validation_0-mae:38.52730	validation_1-mae:40.43118
# [752]	validation_0-mae:38.51193	validation_1-mae:40.41690
# [753]	validation_0-mae:38.50257	validation_1-mae:40.40880
# [754]	validation_0-mae:38.49889	validation_1-mae:40.40611
# [755]	validation_0-mae:38.47997	validation_1-mae:40.38886
# [756]	validation_0-mae:38.47035	validation_1-mae:40.38031
# [757]	validation_0-mae:38.46469	validation_1-mae:40.37575
# [758]	validation_0-mae:38.44499	validation_1-mae:40.35724
# [759]	validation_0-mae:38.44093	validation_1-mae:40.35445
# [760]	validation_0-mae:38.43767	validation_1-mae:40.35251
# [761]	validation_0-mae:38.43364	validation_1-mae:40.34974
# [762]	validation_0-mae:38.42509	validation_1-mae:40.34217
# [763]	validation_0-mae:38.41836	validation_1-mae:40.33631
# [764]	validation_0-mae:38.41430	validation_1-mae:40.33334
# [765]	validation_0-mae:38.40958	validation_1-mae:40.32964
# [766]	validation_0-mae:38.40470	validation_1-mae:40.32562
# [767]	validation_0-mae:38.39599	validation_1-mae:40.31780
# [768]	validation_0-mae:38.39058	validation_1-mae:40.31277
# [769]	validation_0-mae:38.38199	validation_1-mae:40.30518
# [770]	validation_0-mae:38.37748	validation_1-mae:40.30152
# [771]	validation_0-mae:38.37276	validation_1-mae:40.29826
# [772]	validation_0-mae:38.36492	validation_1-mae:40.29142
# [773]	validation_0-mae:38.36097	validation_1-mae:40.28835
# [774]	validation_0-mae:38.35554	validation_1-mae:40.28407
# [775]	validation_0-mae:38.34546	validation_1-mae:40.27521
# [776]	validation_0-mae:38.32925	validation_1-mae:40.25995
# [777]	validation_0-mae:38.32451	validation_1-mae:40.25678
# [778]	validation_0-mae:38.31688	validation_1-mae:40.24975
# [779]	validation_0-mae:38.30590	validation_1-mae:40.23974
# [780]	validation_0-mae:38.29884	validation_1-mae:40.23404
# [781]	validation_0-mae:38.29061	validation_1-mae:40.22657
# [782]	validation_0-mae:38.27608	validation_1-mae:40.21381
# [783]	validation_0-mae:38.26892	validation_1-mae:40.20827
# [784]	validation_0-mae:38.26430	validation_1-mae:40.20550
# [785]	validation_0-mae:38.25392	validation_1-mae:40.19628
# [786]	validation_0-mae:38.24823	validation_1-mae:40.19208
# [787]	validation_0-mae:38.24495	validation_1-mae:40.18968
# [788]	validation_0-mae:38.23747	validation_1-mae:40.18313
# [789]	validation_0-mae:38.21968	validation_1-mae:40.16664
# [790]	validation_0-mae:38.21596	validation_1-mae:40.16378
# [791]	validation_0-mae:38.20991	validation_1-mae:40.16026
# [792]	validation_0-mae:38.20043	validation_1-mae:40.15184
# [793]	validation_0-mae:38.19334	validation_1-mae:40.14593
# [794]	validation_0-mae:38.18196	validation_1-mae:40.13511
# [795]	validation_0-mae:38.17768	validation_1-mae:40.13229
# [796]	validation_0-mae:38.17190	validation_1-mae:40.12770
# [797]	validation_0-mae:38.16186	validation_1-mae:40.11773
# [798]	validation_0-mae:38.15742	validation_1-mae:40.11441
# [799]	validation_0-mae:38.14926	validation_1-mae:40.10704
# [800]	validation_0-mae:38.14039	validation_1-mae:40.09963
# [801]	validation_0-mae:38.13220	validation_1-mae:40.09340
# [802]	validation_0-mae:38.12131	validation_1-mae:40.08384
# [803]	validation_0-mae:38.11787	validation_1-mae:40.08196
# [804]	validation_0-mae:38.10854	validation_1-mae:40.07324
# [805]	validation_0-mae:38.10291	validation_1-mae:40.06901
# [806]	validation_0-mae:38.09504	validation_1-mae:40.06272
# [807]	validation_0-mae:38.08773	validation_1-mae:40.05565
# [808]	validation_0-mae:38.07709	validation_1-mae:40.04650
# [809]	validation_0-mae:38.06584	validation_1-mae:40.03602
# [810]	validation_0-mae:38.06262	validation_1-mae:40.03410
# [811]	validation_0-mae:38.05666	validation_1-mae:40.02880
# [812]	validation_0-mae:38.05328	validation_1-mae:40.02682
# [813]	validation_0-mae:38.04999	validation_1-mae:40.02532
# [814]	validation_0-mae:38.03996	validation_1-mae:40.01608
# [815]	validation_0-mae:38.03399	validation_1-mae:40.01160
# [816]	validation_0-mae:38.02296	validation_1-mae:40.00182
# [817]	validation_0-mae:38.01573	validation_1-mae:39.99628
# [818]	validation_0-mae:38.00469	validation_1-mae:39.98642
# [819]	validation_0-mae:38.00105	validation_1-mae:39.98395
# [820]	validation_0-mae:37.99419	validation_1-mae:39.97931
# [821]	validation_0-mae:37.99137	validation_1-mae:39.97822
# [822]	validation_0-mae:37.98271	validation_1-mae:39.97111
# [823]	validation_0-mae:37.97940	validation_1-mae:39.96918
# [824]	validation_0-mae:37.97231	validation_1-mae:39.96376
# ...
# [8569]	validation_0-mae:21.57350	validation_1-mae:28.51367
# [8570]	validation_0-mae:21.57232	validation_1-mae:28.51322
# [8571]	validation_0-mae:21.57153	validation_1-mae:28.51295
# [8572]	validation_0-mae:21.57064	validation_1-mae:28.51248
# [8573]	validation_0-mae:21.56973	validation_1-mae:28.51219
# [8574]	validation_0-mae:21.56856	validation_1-mae:28.51151
# [8575]	validation_0-mae:21.56758	validation_1-mae:28.51084
# [8576]	validation_0-mae:21.56686	validation_1-mae:28.51050
# [8577]	validation_0-mae:21.56645	validation_1-mae:28.51044
# [8578]	validation_0-mae:21.56492	validation_1-mae:28.50921
# [8579]	validation_0-mae:21.56402	validation_1-mae:28.50875
# [8580]	validation_0-mae:21.56342	validation_1-mae:28.50846
# [8581]	validation_0-mae:21.56281	validation_1-mae:28.50821
# [8582]	validation_0-mae:21.56238	validation_1-mae:28.50801
# [8583]	validation_0-mae:21.56171	validation_1-mae:28.50790
# [8584]	validation_0-mae:21.56082	validation_1-mae:28.50745
# [8585]	validation_0-mae:21.55972	validation_1-mae:28.50649
# [8586]	validation_0-mae:21.55922	validation_1-mae:28.50629
# [8587]	validation_0-mae:21.55851	validation_1-mae:28.50601
# [8588]	validation_0-mae:21.55755	validation_1-mae:28.50562
# [8589]	validation_0-mae:21.55646	validation_1-mae:28.50517
# [8590]	validation_0-mae:21.55606	validation_1-mae:28.50495
# [8591]	validation_0-mae:21.55544	validation_1-mae:28.50467
# [8592]	validation_0-mae:21.55476	validation_1-mae:28.50436
# [8593]	validation_0-mae:21.55436	validation_1-mae:28.50433
# [8594]	validation_0-mae:21.55338	validation_1-mae:28.50382
# [8595]	validation_0-mae:21.55176	validation_1-mae:28.50260
# [8596]	validation_0-mae:21.55092	validation_1-mae:28.50219
# [8597]	validation_0-mae:21.55013	validation_1-mae:28.50181
# [8598]	validation_0-mae:21.54938	validation_1-mae:28.50141
# [8599]	validation_0-mae:21.54842	validation_1-mae:28.50088
# [8600]	validation_0-mae:21.54777	validation_1-mae:28.50048
# [8601]	validation_0-mae:21.54694	validation_1-mae:28.50000
# [8602]	validation_0-mae:21.54538	validation_1-mae:28.49902
# [8603]	validation_0-mae:21.54464	validation_1-mae:28.49857
# [8604]	validation_0-mae:21.54391	validation_1-mae:28.49828
# [8605]	validation_0-mae:21.54313	validation_1-mae:28.49776
# [8606]	validation_0-mae:21.54239	validation_1-mae:28.49728
# [8607]	validation_0-mae:21.54109	validation_1-mae:28.49644
# [8608]	validation_0-mae:21.53963	validation_1-mae:28.49566
# [8609]	validation_0-mae:21.53860	validation_1-mae:28.49507
# [8610]	validation_0-mae:21.53747	validation_1-mae:28.49441
# [8611]	validation_0-mae:21.53689	validation_1-mae:28.49411
# [8612]	validation_0-mae:21.53619	validation_1-mae:28.49379
# [8613]	validation_0-mae:21.53486	validation_1-mae:28.49289
# [8614]	validation_0-mae:21.53421	validation_1-mae:28.49264
# [8615]	validation_0-mae:21.53348	validation_1-mae:28.49230
# [8616]	validation_0-mae:21.53302	validation_1-mae:28.49220
# [8617]	validation_0-mae:21.53231	validation_1-mae:28.49178
# [8618]	validation_0-mae:21.53076	validation_1-mae:28.49062
# [8619]	validation_0-mae:21.52936	validation_1-mae:28.48976
# [8620]	validation_0-mae:21.52805	validation_1-mae:28.48902
# [8621]	validation_0-mae:21.52672	validation_1-mae:28.48825
# [8622]	validation_0-mae:21.52599	validation_1-mae:28.48785
# [8623]	validation_0-mae:21.52475	validation_1-mae:28.48702
# [8624]	validation_0-mae:21.52434	validation_1-mae:28.48690
# [8625]	validation_0-mae:21.52338	validation_1-mae:28.48635
# [8626]	validation_0-mae:21.52302	validation_1-mae:28.48628
# [8627]	validation_0-mae:21.52184	validation_1-mae:28.48568
# [8628]	validation_0-mae:21.52081	validation_1-mae:28.48490
# [8629]	validation_0-mae:21.52013	validation_1-mae:28.48466
# [8630]	validation_0-mae:21.51971	validation_1-mae:28.48448
# [8631]	validation_0-mae:21.51943	validation_1-mae:28.48441
# [8632]	validation_0-mae:21.51875	validation_1-mae:28.48420
# [8633]	validation_0-mae:21.51840	validation_1-mae:28.48407
# [8634]	validation_0-mae:21.51798	validation_1-mae:28.48396
# [8635]	validation_0-mae:21.51679	validation_1-mae:28.48345
# [8636]	validation_0-mae:21.51614	validation_1-mae:28.48301
# [8637]	validation_0-mae:21.51521	validation_1-mae:28.48234
# [8638]	validation_0-mae:21.51283	validation_1-mae:28.48024
# [8639]	validation_0-mae:21.51227	validation_1-mae:28.48004
# [8640]	validation_0-mae:21.51140	validation_1-mae:28.47947
# [8641]	validation_0-mae:21.51057	validation_1-mae:28.47899
# [8642]	validation_0-mae:21.50915	validation_1-mae:28.47801
# [8643]	validation_0-mae:21.50863	validation_1-mae:28.47788
# [8644]	validation_0-mae:21.50803	validation_1-mae:28.47760
# [8645]	validation_0-mae:21.50688	validation_1-mae:28.47691
# [8646]	validation_0-mae:21.50622	validation_1-mae:28.47640
# [8647]	validation_0-mae:21.50522	validation_1-mae:28.47583
# [8648]	validation_0-mae:21.50422	validation_1-mae:28.47540
# [8649]	validation_0-mae:21.50390	validation_1-mae:28.47531
# [8650]	validation_0-mae:21.50159	validation_1-mae:28.47332
# [8651]	validation_0-mae:21.50061	validation_1-mae:28.47284
# [8652]	validation_0-mae:21.49982	validation_1-mae:28.47250
# [8653]	validation_0-mae:21.49883	validation_1-mae:28.47181
# [8654]	validation_0-mae:21.49710	validation_1-mae:28.47062
# [8655]	validation_0-mae:21.49598	validation_1-mae:28.47000
# [8656]	validation_0-mae:21.49515	validation_1-mae:28.46956
# [8657]	validation_0-mae:21.49405	validation_1-mae:28.46900
# [8658]	validation_0-mae:21.49303	validation_1-mae:28.46857
# [8659]	validation_0-mae:21.49174	validation_1-mae:28.46784
# [8660]	validation_0-mae:21.49056	validation_1-mae:28.46728
# [8661]	validation_0-mae:21.48929	validation_1-mae:28.46652
# [8662]	validation_0-mae:21.48794	validation_1-mae:28.46555
# [8663]	validation_0-mae:21.48699	validation_1-mae:28.46494
# [8664]	validation_0-mae:21.48603	validation_1-mae:28.46427
# [8665]	validation_0-mae:21.48508	validation_1-mae:28.46360
# [8666]	validation_0-mae:21.48396	validation_1-mae:28.46309
# [8667]	validation_0-mae:21.48279	validation_1-mae:28.46250
# [8668]	validation_0-mae:21.48207	validation_1-mae:28.46224
# [8669]	validation_0-mae:21.48129	validation_1-mae:28.46179
# [8670]	validation_0-mae:21.48055	validation_1-mae:28.46135
# [8671]	validation_0-mae:21.47973	validation_1-mae:28.46091
# [8672]	validation_0-mae:21.47922	validation_1-mae:28.46065
# [8673]	validation_0-mae:21.47872	validation_1-mae:28.46040
# [8674]	validation_0-mae:21.47772	validation_1-mae:28.45982
# [8675]	validation_0-mae:21.47742	validation_1-mae:28.45970
# [8676]	validation_0-mae:21.47604	validation_1-mae:28.45859
# [8677]	validation_0-mae:21.47478	validation_1-mae:28.45769
# [8678]	validation_0-mae:21.47420	validation_1-mae:28.45736
# [8679]	validation_0-mae:21.47355	validation_1-mae:28.45715
# [8680]	validation_0-mae:21.47264	validation_1-mae:28.45667
# [8681]	validation_0-mae:21.47170	validation_1-mae:28.45616
# [8682]	validation_0-mae:21.47133	validation_1-mae:28.45601
# [8683]	validation_0-mae:21.47078	validation_1-mae:28.45582
# [8684]	validation_0-mae:21.46960	validation_1-mae:28.45518
# [8685]	validation_0-mae:21.46828	validation_1-mae:28.45422
# [8686]	validation_0-mae:21.46738	validation_1-mae:28.45375
# [8687]	validation_0-mae:21.46663	validation_1-mae:28.45341
# [8688]	validation_0-mae:21.46616	validation_1-mae:28.45329
# [8689]	validation_0-mae:21.46562	validation_1-mae:28.45300
# [8690]	validation_0-mae:21.46469	validation_1-mae:28.45253
# [8691]	validation_0-mae:21.46382	validation_1-mae:28.45196
# [8692]	validation_0-mae:21.46268	validation_1-mae:28.45106
# [8693]	validation_0-mae:21.46111	validation_1-mae:28.44999
# [8694]	validation_0-mae:21.46011	validation_1-mae:28.44942
# [8695]	validation_0-mae:21.45907	validation_1-mae:28.44879
# [8696]	validation_0-mae:21.45769	validation_1-mae:28.44794
# [8697]	validation_0-mae:21.45703	validation_1-mae:28.44761
# [8698]	validation_0-mae:21.45607	validation_1-mae:28.44713
# [8699]	validation_0-mae:21.45448	validation_1-mae:28.44610
# [8700]	validation_0-mae:21.45310	validation_1-mae:28.44528
# [8701]	validation_0-mae:21.45182	validation_1-mae:28.44451
# [8702]	validation_0-mae:21.45134	validation_1-mae:28.44438
# [8703]	validation_0-mae:21.45076	validation_1-mae:28.44409
# [8704]	validation_0-mae:21.44994	validation_1-mae:28.44362
# [8705]	validation_0-mae:21.44905	validation_1-mae:28.44317
# [8706]	validation_0-mae:21.44843	validation_1-mae:28.44297
# [8707]	validation_0-mae:21.44706	validation_1-mae:28.44209
# [8708]	validation_0-mae:21.44554	validation_1-mae:28.44069
# [8709]	validation_0-mae:21.44455	validation_1-mae:28.44013
# [8710]	validation_0-mae:21.44383	validation_1-mae:28.43971
# [8711]	validation_0-mae:21.44278	validation_1-mae:28.43910
# [8712]	validation_0-mae:21.44139	validation_1-mae:28.43806
# [8713]	validation_0-mae:21.44058	validation_1-mae:28.43760
# [8714]	validation_0-mae:21.43977	validation_1-mae:28.43723
# [8715]	validation_0-mae:21.43882	validation_1-mae:28.43669
# [8716]	validation_0-mae:21.43789	validation_1-mae:28.43625
# [8717]	validation_0-mae:21.43697	validation_1-mae:28.43556
# [8718]	validation_0-mae:21.43634	validation_1-mae:28.43513
# [8719]	validation_0-mae:21.43491	validation_1-mae:28.43420
# [8720]	validation_0-mae:21.43402	validation_1-mae:28.43374
# [8721]	validation_0-mae:21.43263	validation_1-mae:28.43270
# [8722]	validation_0-mae:21.43190	validation_1-mae:28.43232
# [8723]	validation_0-mae:21.43004	validation_1-mae:28.43107
# [8724]	validation_0-mae:21.42911	validation_1-mae:28.43052
# [8725]	validation_0-mae:21.42870	validation_1-mae:28.43032
# [8726]	validation_0-mae:21.42745	validation_1-mae:28.42950
# [8727]	validation_0-mae:21.42710	validation_1-mae:28.42941
# [8728]	validation_0-mae:21.42639	validation_1-mae:28.42912
# [8729]	validation_0-mae:21.42525	validation_1-mae:28.42859
# [8730]	validation_0-mae:21.42418	validation_1-mae:28.42815
# [8731]	validation_0-mae:21.42356	validation_1-mae:28.42794
# [8732]	validation_0-mae:21.42254	validation_1-mae:28.42750
# [8733]	validation_0-mae:21.42134	validation_1-mae:28.42672
# [8734]	validation_0-mae:21.42036	validation_1-mae:28.42614
# [8735]	validation_0-mae:21.41918	validation_1-mae:28.42549
# [8736]	validation_0-mae:21.41885	validation_1-mae:28.42546
# [8737]	validation_0-mae:21.41842	validation_1-mae:28.42517
# [8738]	validation_0-mae:21.41745	validation_1-mae:28.42477
# [8739]	validation_0-mae:21.41701	validation_1-mae:28.42452
# [8740]	validation_0-mae:21.41665	validation_1-mae:28.42443
# [8741]	validation_0-mae:21.41638	validation_1-mae:28.42440
# [8742]	validation_0-mae:21.41605	validation_1-mae:28.42436
# [8743]	validation_0-mae:21.41525	validation_1-mae:28.42381
# [8744]	validation_0-mae:21.41496	validation_1-mae:28.42377
# [8745]	validation_0-mae:21.41343	validation_1-mae:28.42275
# [8746]	validation_0-mae:21.41191	validation_1-mae:28.42170
# [8747]	validation_0-mae:21.41072	validation_1-mae:28.42087
# [8748]	validation_0-mae:21.40978	validation_1-mae:28.42040
# [8749]	validation_0-mae:21.40878	validation_1-mae:28.41996
# [8750]	validation_0-mae:21.40808	validation_1-mae:28.41950
# [8751]	validation_0-mae:21.40684	validation_1-mae:28.41867
# [8752]	validation_0-mae:21.40618	validation_1-mae:28.41825
# [8753]	validation_0-mae:21.40517	validation_1-mae:28.41768
# [8754]	validation_0-mae:21.40425	validation_1-mae:28.41695
# [8755]	validation_0-mae:21.40310	validation_1-mae:28.41627
# [8756]	validation_0-mae:21.40280	validation_1-mae:28.41629
# [8757]	validation_0-mae:21.40182	validation_1-mae:28.41579
# [8758]	validation_0-mae:21.40118	validation_1-mae:28.41549
# [8759]	validation_0-mae:21.40010	validation_1-mae:28.41486
# [8760]	validation_0-mae:21.39981	validation_1-mae:28.41482
# [8761]	validation_0-mae:21.39886	validation_1-mae:28.41426
# [8762]	validation_0-mae:21.39804	validation_1-mae:28.41389
# [8763]	validation_0-mae:21.39672	validation_1-mae:28.41302
# [8764]	validation_0-mae:21.39511	validation_1-mae:28.41204
# [8765]	validation_0-mae:21.39417	validation_1-mae:28.41163
# [8766]	validation_0-mae:21.39290	validation_1-mae:28.41073
# [8767]	validation_0-mae:21.39200	validation_1-mae:28.41028
# [8768]	validation_0-mae:21.39093	validation_1-mae:28.40965
# [8769]	validation_0-mae:21.38993	validation_1-mae:28.40894
# [8770]	validation_0-mae:21.38880	validation_1-mae:28.40822
# [8771]	validation_0-mae:21.38813	validation_1-mae:28.40794
# [8772]	validation_0-mae:21.38661	validation_1-mae:28.40687
# [8773]	validation_0-mae:21.38562	validation_1-mae:28.40634
# [8774]	validation_0-mae:21.38470	validation_1-mae:28.40604
# [8775]	validation_0-mae:21.38354	validation_1-mae:28.40551
# [8776]	validation_0-mae:21.38248	validation_1-mae:28.40489
# [8777]	validation_0-mae:21.38145	validation_1-mae:28.40433
# [8778]	validation_0-mae:21.38013	validation_1-mae:28.40343
# [8779]	validation_0-mae:21.37946	validation_1-mae:28.40298
# [8780]	validation_0-mae:21.37860	validation_1-mae:28.40250
# [8781]	validation_0-mae:21.37751	validation_1-mae:28.40195
# [8782]	validation_0-mae:21.37691	validation_1-mae:28.40163
# [8783]	validation_0-mae:21.37583	validation_1-mae:28.40110
# [8784]	validation_0-mae:21.37533	validation_1-mae:28.40085
# [8785]	validation_0-mae:21.37394	validation_1-mae:28.39997
# [8786]	validation_0-mae:21.37324	validation_1-mae:28.39946
# [8787]	validation_0-mae:21.37166	validation_1-mae:28.39833
# [8788]	validation_0-mae:21.37103	validation_1-mae:28.39807
# [8789]	validation_0-mae:21.36973	validation_1-mae:28.39731
# [8790]	validation_0-mae:21.36783	validation_1-mae:28.39577
# [8791]	validation_0-mae:21.36684	validation_1-mae:28.39522
# [8792]	validation_0-mae:21.36546	validation_1-mae:28.39431
# [8793]	validation_0-mae:21.36421	validation_1-mae:28.39343
# [8794]	validation_0-mae:21.36325	validation_1-mae:28.39303
# [8795]	validation_0-mae:21.36204	validation_1-mae:28.39212
# [8796]	validation_0-mae:21.36104	validation_1-mae:28.39168
# [8797]	validation_0-mae:21.36000	validation_1-mae:28.39115
# [8798]	validation_0-mae:21.35909	validation_1-mae:28.39070
# [8799]	validation_0-mae:21.35784	validation_1-mae:28.38984
# [8800]	validation_0-mae:21.35667	validation_1-mae:28.38920
# [8801]	validation_0-mae:21.35548	validation_1-mae:28.38852
# [8802]	validation_0-mae:21.35415	validation_1-mae:28.38749
# [8803]	validation_0-mae:21.35333	validation_1-mae:28.38712
# [8804]	validation_0-mae:21.35288	validation_1-mae:28.38701
# [8805]	validation_0-mae:21.35243	validation_1-mae:28.38688
# [8806]	validation_0-mae:21.35190	validation_1-mae:28.38671
# [8807]	validation_0-mae:21.35131	validation_1-mae:28.38643
# [8808]	validation_0-mae:21.35088	validation_1-mae:28.38637
# [8809]	validation_0-mae:21.35056	validation_1-mae:28.38633
# [8810]	validation_0-mae:21.34956	validation_1-mae:28.38569
# [8811]	validation_0-mae:21.34831	validation_1-mae:28.38483
# [8812]	validation_0-mae:21.34735	validation_1-mae:28.38428
# [8813]	validation_0-mae:21.34623	validation_1-mae:28.38365
# [8814]	validation_0-mae:21.34590	validation_1-mae:28.38359
# [8815]	validation_0-mae:21.34561	validation_1-mae:28.38352
# [8816]	validation_0-mae:21.34500	validation_1-mae:28.38315
# [8817]	validation_0-mae:21.34454	validation_1-mae:28.38294
# [8818]	validation_0-mae:21.34419	validation_1-mae:28.38287
# [8819]	validation_0-mae:21.34368	validation_1-mae:28.38263
# [8820]	validation_0-mae:21.34279	validation_1-mae:28.38219
# [8821]	validation_0-mae:21.34204	validation_1-mae:28.38187
# [8822]	validation_0-mae:21.34093	validation_1-mae:28.38130
# [8823]	validation_0-mae:21.34035	validation_1-mae:28.38106
# [8824]	validation_0-mae:21.33931	validation_1-mae:28.38065
# [8825]	validation_0-mae:21.33832	validation_1-mae:28.38022
# [8826]	validation_0-mae:21.33782	validation_1-mae:28.38001
# [8827]	validation_0-mae:21.33738	validation_1-mae:28.37974
# [8828]	validation_0-mae:21.33584	validation_1-mae:28.37873
# [8829]	validation_0-mae:21.33496	validation_1-mae:28.37828
# [8830]	validation_0-mae:21.33439	validation_1-mae:28.37822
# [8831]	validation_0-mae:21.33379	validation_1-mae:28.37807
# [8832]	validation_0-mae:21.33330	validation_1-mae:28.37789
# [8833]	validation_0-mae:21.33304	validation_1-mae:28.37778
# [8834]	validation_0-mae:21.33267	validation_1-mae:28.37761
# [8835]	validation_0-mae:21.33237	validation_1-mae:28.37761
# [8836]	validation_0-mae:21.33212	validation_1-mae:28.37760
# [8837]	validation_0-mae:21.33136	validation_1-mae:28.37729
# [8838]	validation_0-mae:21.33032	validation_1-mae:28.37675
# [8839]	validation_0-mae:21.32999	validation_1-mae:28.37665

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Plotting for All Feature Versions with Default Hyperparameters

# %%
all_results = pd.read_csv("/kaggle/input/feature-eng-res/trainvalid_iteration_all.csv").drop("Unnamed: 0",axis=1)
all_results.rename(columns={"train": "train_all", "validation": "validation_all"}, inplace=True)
iter_1 = pd.read_csv("/kaggle/input/feature-eng-res/trainvalid_iteration_1.csv").drop("Unnamed: 0",axis=1)
iter_1.rename(columns={"train": "train_1", "validation": "validation_1"}, inplace=True)
iter_2 = pd.read_csv("/kaggle/input/feature-eng-res/trainvalid_iteration_2.csv").drop("Unnamed: 0",axis=1)
iter_2.rename(columns={"train": "train_2", "validation": "validation_2"}, inplace=True)
iter_3 = pd.read_csv("/kaggle/input/feature-eng-res/trainvalid_iteration_3.csv").drop("Unnamed: 0",axis=1)
iter_3.rename(columns={"train": "train_3", "validation": "validation_3"}, inplace=True)

# %%
results_df = (
    all_results.merge(iter_1, left_index=True, right_index=True, how="outer")
    .merge(iter_2, left_index=True, right_index=True, how="outer")
    .merge(iter_3, left_index=True, right_index=True, how="outer")
)
results_df

# %%
# Retrieve performance metrics
plt.rc('font', family='serif', size=8)
estimators = results_df.shape[0]
x_axis = range(0, estimators)

# Plot
fig, ax = plt.subplots(figsize=[8,6])
ax.plot(x_axis, results_df["train_all"], label='all features train',linestyle='dotted', color='g', linewidth=.75)
ax.plot(x_axis, results_df["validation_all"], label='all features validation',linestyle='-', color='g', linewidth=.75)
ax.plot(x_axis, results_df["train_1"], label='feature set 1 train',linestyle='dotted', color='brown', linewidth=.75)
ax.plot(x_axis, results_df["validation_1"], label='feature set 1 validation',linestyle='-', color='brown', linewidth=.75)
ax.plot(x_axis, results_df["train_2"], label='feature set 2 train',linestyle='dotted', color='r', linewidth=.75)
ax.plot(x_axis, results_df["validation_2"], label='feature set 2 validation',linestyle='-', color='r', linewidth=.75)
ax.plot(x_axis, results_df["train_3"], label='feature set 3 train',linestyle='dotted', color='b', linewidth=.75)
ax.plot(x_axis, results_df["validation_3"], label='feature set 3 validation',linestyle='-', color='b', linewidth=.75)
ax.legend()
plt.ylabel('MAE')
plt.xlabel('n estimators')
plt.title('Train and Validation MAE')
plt.show()

# %% [markdown]
# ## Plotting for Selected Feature V3 with Default Hyperparamaters vs Selected Features V3 with Best Hyperparameters

# %%
def_hyperparams = pd.read_csv("/kaggle/input/feature-eng-res/trainvalid_iteration_3_def.csv").drop("Unnamed: 0",axis=1)
best_hyperparams = pd.read_csv("/kaggle/input/feature-eng-res/trainvalid_iteration_3_best.csv").drop("Unnamed: 0",axis=1)

# %%
results_df = (
    def_hyperparams.merge(best_hyperparams, left_index=True, right_index=True, how="outer")
)
results_df

# %%
# Retrieve performance metrics
plt.rc('font', family='serif', size=8)
estimators = results_df.shape[0]
x_axis = range(0, estimators)

# Plot
fig, ax = plt.subplots(figsize=[8,6])
ax.plot(x_axis, results_df["train_x"], label='best features default hyperparams train',linestyle='dotted', color='g', linewidth=.75)
ax.plot(x_axis, results_df["validation_x"], label='best features default hyperparams validation',linestyle='-', color='g', linewidth=.75)
ax.plot(x_axis, results_df["train_y"], label='best features best hyperparams train',linestyle='dotted', color='brown', linewidth=.75)
ax.plot(x_axis, results_df["validation_y"], label='best features best hyperparams validation',linestyle='-', color='brown', linewidth=.75)
ax.legend()
plt.ylabel('MAE')
plt.xlabel('n estimators')
plt.title('Train and Validation MAE')
# plt.show()
plt.savefig('Train and Validation MAE.png', dpi=300)

# %% [markdown]
# ## Feature Importance

# %%
xgb.plot_importance(final_model, importance_type="weight")

# %% [markdown]
# # Submission
#
# - uses the python time-series API provided by Enefit for the Kaggle competition

# %%
def create_revealed_targets_test(data, previous_revealed_targets, max_lags):
    '''🎯 Create new test data based on previous_revealed_targets and N_day_lags 🎯 ''' 
    for count, revealed_targets in enumerate(previous_revealed_targets) :
        day_lag = count + 2
        
        # Get hour
        revealed_targets['hour'] = pd.to_datetime(revealed_targets['datetime'], utc= True).dt.hour
        
        # Select columns and rename target
        revealed_targets = revealed_targets[['hour', 'prediction_unit_id', 'is_consumption', 'target']]
        revealed_targets = revealed_targets.rename(columns = {"target" : f"target_{day_lag}_days_ago"})
        
        
        # Add past revealed targets
        data = pd.merge(data, revealed_targets, how='left', on=['hour', 'prediction_unit_id', 'is_consumption'])
        
    # If revealed_target_columns not available, replace by nan
    all_revealed_columns = [f"target_{day_lag}_days_ago" for day_lag in range(2, max_lags+1)]
    missing_columns = list(set(all_revealed_columns) - set(data.columns))
    data[missing_columns] = np.nan 
    
    return data

# %%
def generate_test_set(test, client, historical_weather,forecast_weather, electricity_prices, gas_prices):
    
    forecast_weather[["latitude",'longitude']] = forecast_weather[["latitude",'longitude']].astype(float).round(decimals=1)
    forecast_weather[["latitude",'longitude']]

    forecast_weather= forecast_weather.merge(locations, how='left', on=['longitude','latitude'])
    forecast_weather.dropna(axis= 0, inplace= True)
    forecast_weather['county'] = forecast_weather['county'].astype(int)
    forecast_weather.drop(['origin_datetime', 'latitude',
                               'longitude', 'hours_ahead'], axis=1, inplace= True)
    forecast_weather.rename(columns={'forecast_datetime': 'datetime'}, inplace= True)

    #Converting (datetime) column to datetime
    forecast_weather['datetime']= pd.to_datetime(forecast_weather['datetime'], utc= True)

    """Grouping all forecast_weather columns mean values by hour, So each hour will have the mean values of the forecast_weather columns""" 
    forecast_weather_datetime= forecast_weather.groupby([forecast_weather['datetime'].dt.to_period('h')])[list(forecast_weather.drop(['county','datetime'], axis= 1).columns)].mean().reset_index()
    #After converting the (datetime) column to hour period for the groupby we convert it back to datetime
    forecast_weather_datetime['datetime']= pd.to_datetime(forecast_weather_datetime['datetime'].dt.to_timestamp(), utc=True)

    """Grouping all forecast_weather columns mean values by hour and county, So each hour and county will have the mean values of the forecast_weather columns for each county""" 
    forecast_weather_datetime_county= forecast_weather.groupby(['county',forecast_weather['datetime'].
                              dt.to_period('h')])[list(forecast_weather.drop(['county',
                                                                              'datetime'], axis= 1)
                                                       .columns)].mean().reset_index()

    #After converting the (datetime) column to hour period for the groupby we convert it back to datetime
    forecast_weather_datetime_county['datetime']= pd.to_datetime(
        forecast_weather_datetime_county['datetime'].dt.to_timestamp(), utc=True)



    #Rounding the (latitude) and (longitude) for 1 decimal fraction           
    historical_weather[['latitude', 'longitude']] = historical_weather[['latitude', 'longitude']].astype(float).round(1)

    #Merging counties in locations data with the coordinations in the historical_weather data
    historical_weather= historical_weather.merge(locations, how='left', on=['longitude','latitude'])    

    #Dropping nan values to remov
    historical_weather.dropna(axis= 0, inplace= True)

    #Dropping the columns we won't need
    historical_weather.drop(['latitude', 'longitude'], axis=1, inplace= True)

    #Converting (county) to integer
    historical_weather['county'] = historical_weather['county'].astype('int64')

    #Converting (datetime) column to datetime
    historical_weather['datetime']= pd.to_datetime(historical_weather['datetime'], utc= True)

    """Grouping all historical_weather columns mean values by hour, So each hour will have the mean values of the historical_weather columns"""     
    hist_weather_datetime= historical_weather.groupby([historical_weather['datetime'].dt.to_period('h')])[list(historical_weather.drop(['county','datetime'], axis= 1).columns)].mean().reset_index()    

    #After converting the (datetime) column to hour period for the groupby we convert it back to datetime
    hist_weather_datetime['datetime']= pd.to_datetime(
        hist_weather_datetime['datetime'].dt.to_timestamp(), utc=True)

    #Merging (data_block_id) back after dropping it in the last step | (data_block_id will be used to merge with train data)
    hist_weather_datetime= hist_weather_datetime.merge(historical_weather[['datetime']], how='left', on='datetime')

    """Grouping all historical_weather columns mean values by hour and county, So each hour will have the mean values of the historical_weather columns for each county"""   
    hist_weather_datetime_county= historical_weather.groupby(['county',historical_weather['datetime'].dt.to_period('h')])[list(historical_weather.drop(['county','datetime'], axis= 1).columns)].mean().reset_index() 

    #After converting the (datetime) column to hour period for the groupby we convert it back to datetime
    hist_weather_datetime_county['datetime']= pd.to_datetime(hist_weather_datetime_county['datetime'].dt.to_timestamp(), utc=True)

    #Merging (data_block_id) back after dropping it in the last step
    hist_weather_datetime_county= hist_weather_datetime_county.merge(historical_weather[['datetime']], how='left', on='datetime')

    hist_weather_datetime['hour']= hist_weather_datetime['datetime'].dt.hour
    hist_weather_datetime_county['hour']= hist_weather_datetime_county['datetime'].dt.hour

    #Dropping duplicates and (datetime) column
    hist_weather_datetime.drop_duplicates(inplace=True)
    hist_weather_datetime_county.drop_duplicates(inplace=True)
    hist_weather_datetime.drop('datetime', axis= 1, inplace= True)
    hist_weather_datetime_county.drop('datetime', axis= 1, inplace= True)

    electricity_prices["forecast_date"] = pd.to_datetime(electricity_prices["forecast_date"], utc=True)
    electricity_prices["hour"] = electricity_prices["forecast_date"].dt.hour
    
    # Remove timezone information from both columns
    test['datetime'] = test['datetime'].dt.tz_localize(None)
    forecast_weather_datetime['datetime'] = forecast_weather_datetime['datetime'].dt.tz_localize(None)
    forecast_weather_datetime_county['datetime'] = forecast_weather_datetime_county['datetime'].dt.tz_localize(None)

    # Merge other necessary dataframes

    # Electricity Prices
    test = test.merge(electricity_prices[["hour", "euros_per_mwh"]], on=["hour"], how="left")
    
    # Client
    test = test.merge(client.drop("date",axis=1), on=['county', 'is_business', 'product_type'], how="left")

    # Forecast Weather Datetime
    test = test.merge(forecast_weather_datetime, how='left', on=['datetime'])

    # Forecast Weather Datetime County
    test = test.merge(forecast_weather_datetime_county, how='left', on=['datetime', 'county'],suffixes= ('_fcast_mean','_fcast_mean_by_county'))

    # Historical Weather Datetime
    test = test.merge(hist_weather_datetime, how='left', on=['hour'])

    # Historical Weather Datetime County
    test = test.merge(hist_weather_datetime_county, how='left', on= ['county', 'hour'],suffixes= ('_hist_mean','_hist_mean_by_county'))
    test = test.merge(county_details, on=["county"], how="left")

    
    test['date'] = test['datetime'].dt.normalize()
    
    # Gas Prices
    gas_prices['date'] = pd.to_datetime(gas_prices['forecast_date'])
    
    test = test.merge(gas_prices[["date", "lowest_price_per_mwh", "highest_price_per_mwh"]], left_on="date", right_on="date", how="left")

    test.drop('date', axis=1, inplace=True)

    test[['county','product_type','is_consumption']] = test[['county','product_type','is_consumption']].astype(object)
    
    
    test['county'] = test['county'].astype(int)
    test['product_type'] = test['product_type'].astype(int)
    
    return test

# %%
# Reload enefit environment (only in debug mode, otherwise the submission will fail)
debug = False # set this to False if submitting
env = enefit.make_env()
if debug :
    enefit.make_env.__called__ = False
    type(env)._state = type(type(env)._state).__dict__['INIT']
    iter_test = env.iter_test()
else:

    iter_test = env.iter_test()

# %%
previous_revealed_targets = []

for (test, revealed_targets, client, historical_weather,
        forecast_weather, electricity_prices, gas_prices, sample_prediction) in iter_test:
    
    test = test.rename(columns={'prediction_datetime':'datetime'})
    test["datetime"] = pd.to_datetime(test["datetime"], utc=True)
    test['hour'] = test['datetime'].dt.hour
    test['day_of_week'] = test['datetime'].dt.dayofweek
    test['day'] = test['datetime'].dt.day
    test['month'] = test['datetime'].dt.month
    test['year'] = test['datetime'].dt.year
    test['quarter'] = test['datetime'].dt.quarter
    test['dayofyear'] = test['datetime'].dt.dayofyear
    test['sin_hour']= (np.pi * np.sin(test['hour']) / 12)
    test['cos_hour']= (np.pi * np.cos(test['hour']) / 12)
    test['sin_dayofyear']= (np.pi * np.sin(test['dayofyear']) / 183)
    test['cos_dayofyear']= (np.pi * np.cos(test['dayofyear']) / 183)

    num_lag = 7
    previous_revealed_targets.insert(0, revealed_targets)
    if len(previous_revealed_targets) == num_lag:
        previous_revealed_targets.pop()
        
    X_test = create_revealed_targets_test(data=test.copy(), previous_revealed_targets = previous_revealed_targets.copy(), max_lags = num_lag)
    X_test['target_mean']= X_test[[f'target_{i}_days_ago' for i in range(2, num_lag+1)]].mean(1)
    X_test['target_std']= X_test[[f'target_{i}_days_ago' for i in range(2, num_lag+1)]].std(1)
    X_test['target_var']= X_test[[f'target_{i}_days_ago' for i in range(2, num_lag+1)]].var(1)
    for lag in range(2,num_lag+1):
        X_test[f"target_diff_{lag}_days_ago"] = X_test[f"target_{lag}_days_ago"]
        X_test[f"target_delta_{lag}_days_ago"] = X_test[f"target_diff_{lag}_days_ago"] / lag

    X_test = generate_test_set(X_test, client, historical_weather,forecast_weather, electricity_prices, gas_prices)
    for col in log_this_columns:
        X_test[f"{col}_log"] = np.where((X_test[col])!= 0, np.log(X_test[col]),0)
    X_test = X_test[features]
    
    sample_prediction['target'] = final_model.predict(X_test) 
    env.predict(sample_prediction)
